# %%
pip install imageio
# Out:
# Collecting imageio
#   Downloading imageio-2.36.0-py3-none-any.whl (315 kB)
#      -------------------------------------- 315.4/315.4 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=8.3.2 in c:\users\hera\appdata\roaming\python\python310\site-packages (from imageio) (10.4.0)
# Requirement already satisfied: numpy in c:\users\hera\appdata\roaming\python\python310\site-packages (from imageio) (2.1.0)
# Installing collected packages: imageio
# Successfully installed imageio-2.36.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hera\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hera\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hera\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hera\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hera\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hera\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hera\anaconda3\lib\site-packages)

# %%
import os
import array
import numpy as np
import imageio  # Use imageio for saving image
from concurrent.futures import ThreadPoolExecutor # for parallelization
import time
import shutil
import pandas as pd

# %% [markdown]
# To process .byte file to .png
#
# 1. Removed the addresses as addresses don't contain meaningful value
#
# 2. Processing of unknown '??' values:
# * Ignore (we are choosing to do this, but size of the byte file might be altered)
# * Alternative: convert to 00 (the original structure of the byte files is retained, but some are a huge chuck of BLACK lol)

# %%
start = time.time()
## THIS IS FOR ALL FILES IN THE TRAIN FOLDER. USES PARALLELIZATION

# Define the directory where the .bytes files are stored and the output directory
train_dir = 'train'  # Folder containing .bytes files
output_dir = 'byte_images'  # Folder to save the converted PNG images

# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Function to clean and convert a single .bytes file to a PNG image
def clean_and_convert_bytes_to_png(file):
    if file.endswith("bytes"):  # Only process files with the '.bytes' extension
        file_base = file.split('.')[0]

        # Open the original .bytes file from the /train folder
        with open(os.path.join(train_dir, file), "r") as fp:
            hex_values = []
            for line in fp:
                # Remove the address (the first element) and keep only the bytes
                byte_values = line.rstrip().split(" ")[1:]
                hex_values.extend(byte_values)  # Add cleaned byte values to the list

        # # Convert hex values to integers, ignoring unknown '??' bytes
        # byte_values = [int(hv, 16) for hv in hex_values if hv != '??']

        # Convert hex values to integers, replacing unknown '??' bytes with '00'
        byte_values = [int(hv, 16) if hv != '??' else 0 for hv in hex_values]

        # Determine the file size in bytes and calculate image dimensions
        ln = len(byte_values)  # Number of byte values
        width = int(np.ceil(np.sqrt(ln)))  # Image width is the square root of the file size
        rem = ln % width  # Remainder for reshaping

        # Truncate any extra bytes that don't fit into the shape
        byte_values = byte_values[:ln - rem]

        # Reshape the byte values into a 2D array for image representation
        g = np.reshape(byte_values, (len(byte_values) // width, width))
        g = np.uint8(g)  # Convert the data to uint8 type

        # Save the grayscale image using imageio
        output_image_path = os.path.join(output_dir, f'{file_base}.png')
        imageio.imwrite(output_image_path, g)

        print(f"Converted {file} to {output_image_path}")

# List of files in the /train directory
files = os.listdir(train_dir)

# Use ThreadPoolExecutor to parallelize the cleaning and conversion process
with ThreadPoolExecutor() as executor:
    executor.map(clean_and_convert_bytes_to_png, files)

print("Conversion of byte files to PNG images completed.")
end = time.time()

print("Time taken: {} m {} s".format(int((end-start)//60), int((end-start)%60)))
# Out:
# Converted 04hSzLv5s2TDYPlcgpHB.bytes to byte_images\04hSzLv5s2TDYPlcgpHB.png
# Converted 0aVNj3qFgEZI6Akf4Kuv.bytes to byte_images\0aVNj3qFgEZI6Akf4Kuv.png
# Converted 0eN9lyQfwmTVk7C2ZoYp.bytes to byte_images\0eN9lyQfwmTVk7C2ZoYp.png
# Converted 0hZEqJ5eMVjU21HAG7Ii.bytes to byte_images\0hZEqJ5eMVjU21HAG7Ii.png
# Converted 08BX5Slp2I1FraZWbc6j.bytes to byte_images\08BX5Slp2I1FraZWbc6j.png
# Converted 0DbLeKSoxu47wjqVHsi9.bytes to byte_images\0DbLeKSoxu47wjqVHsi9.png
# Converted 0GUIi7xAlODwZ4YBenNM.bytes to byte_images\0GUIi7xAlODwZ4YBenNM.png
# Converted 0EL7OGZKozbiNCVP61gk.bytes to byte_images\0EL7OGZKozbiNCVP61gk.png
# Converted 0gcZkSFr7VnEmLPbTxUe.bytes to byte_images\0gcZkSFr7VnEmLPbTxUe.png
# Converted 0ItXlAUOhK8ZYdDf7HW4.bytes to byte_images\0ItXlAUOhK8ZYdDf7HW4.png
# Converted 05aiMRw13bYWqZ8OHvjl.bytes to byte_images\05aiMRw13bYWqZ8OHvjl.png
# Converted 065EZhxgbLRSHsB87uIF.bytes to byte_images\065EZhxgbLRSHsB87uIF.png
# Converted 0gxJ1YmwFUvnOzoM8N53.bytes to byte_images\0gxJ1YmwFUvnOzoM8N53.png
# Converted 0Iv6U2hbcP1xeBitW5Oo.bytes to byte_images\0Iv6U2hbcP1xeBitW5Oo.png
# Converted 0I4ZVvngsAatm8fzD3pk.bytes to byte_images\0I4ZVvngsAatm8fzD3pk.png
# Converted 0mgFnqeLAMr7jthUYRTv.bytes to byte_images\0mgFnqeLAMr7jthUYRTv.png
# Converted 0NyfGXt8nmlK72Q9Irhs.bytes to byte_images\0NyfGXt8nmlK72Q9Irhs.png
# Converted 0hZqVRKkw7GfMdpalLiN.bytes to byte_images\0hZqVRKkw7GfMdpalLiN.png
# Converted 0njs7MJQObCY8ABgykiP.bytes to byte_images\0njs7MJQObCY8ABgykiP.png
# Converted 0S7z4qxYTHPUDO8fgIyA.bytes to byte_images\0S7z4qxYTHPUDO8fgIyA.png
# Converted 0sH5GdO3LpZwMbPaXjfN.bytes to byte_images\0sH5GdO3LpZwMbPaXjfN.png
# Converted 0PlfqyKM1JtYZx2me5FU.bytes to byte_images\0PlfqyKM1JtYZx2me5FU.png
# Converted 0LAXajqhQy7po16dw8Tx.bytes to byte_images\0LAXajqhQy7po16dw8Tx.png
# Converted 0K4sTCLtrIJ5SinQbe7u.bytes to byte_images\0K4sTCLtrIJ5SinQbe7u.png
# Converted 0rGlKyvn5Vo67RaDhPti.bytes to byte_images\0rGlKyvn5Vo67RaDhPti.png
# Converted 0rgi8OfjvwKbA57IXVcE.bytes to byte_images\0rgi8OfjvwKbA57IXVcE.png
# Converted 0M7aSiE9csDzkmfKheVt.bytes to byte_images\0M7aSiE9csDzkmfKheVt.png
# Converted 0qV43bnIcBDPF1WlG6tJ.bytes to byte_images\0qV43bnIcBDPF1WlG6tJ.png
# Converted 0PREAmkFZjrftD3LiwOV.bytes to byte_images\0PREAmkFZjrftD3LiwOV.png
# Converted 0MmZ8j5pn2R3VG9wlxYi.bytes to byte_images\0MmZ8j5pn2R3VG9wlxYi.png
# Converted 0pXDqTLSebKWgaUOdnVE.bytes to byte_images\0pXDqTLSebKWgaUOdnVE.png
# Converted 0SIqXMkDBWKE8s9pQaOv.bytes to byte_images\0SIqXMkDBWKE8s9pQaOv.png
# Converted 0VnTurd7B4YsH63wUGJ2.bytes to byte_images\0VnTurd7B4YsH63wUGJ2.png
# Converted 0XrH26wcU1ASsvK5ZqhD.bytes to byte_images\0XrH26wcU1ASsvK5ZqhD.png
# Converted 0wkFafuhqSr1Z5J7K6C9.bytes to byte_images\0wkFafuhqSr1Z5J7K6C9.png
# Converted 0tZy7jgOKCIJslPRvrop.bytes to byte_images\0tZy7jgOKCIJslPRvrop.png
# Converted 0sLBvJeYl5UkiRzV1atI.bytes to byte_images\0sLBvJeYl5UkiRzV1atI.png
# Converted 0sM2atqTo48GgnFwhQXu.bytes to byte_images\0sM2atqTo48GgnFwhQXu.png
# Converted 0SHJ2aOnMCUGdLZrTQDV.bytes to byte_images\0SHJ2aOnMCUGdLZrTQDV.png
# Converted 0V6UmdMg7wQGXslAzORJ.bytes to byte_images\0V6UmdMg7wQGXslAzORJ.png
# Converted 18te652nLyCi3IrZqMOJ.bytes to byte_images\18te652nLyCi3IrZqMOJ.png
# Converted 0ZAJlqmphO4fjnVB6bMz.bytes to byte_images\0ZAJlqmphO4fjnVB6bMz.png
# Converted 0uZcAvaHLitbWmC1QMXf.bytes to byte_images\0uZcAvaHLitbWmC1QMXf.png
# Converted 10H9detwuiZByNSRMmxf.bytes to byte_images\10H9detwuiZByNSRMmxf.png
# Converted 0YCvp8xd4rjiDMKFV9PA.bytes to byte_images\0YCvp8xd4rjiDMKFV9PA.png
# Converted 0YIPlyX3fbNs2ntJRGgH.bytes to byte_images\0YIPlyX3fbNs2ntJRGgH.png
# Converted 13FZ9DOhywk78sJiVULu.bytes to byte_images\13FZ9DOhywk78sJiVULu.pngConverted 1bL4yiwCUvSOg7tBJudf.bytes to byte_images\1bL4yiwCUvSOg7tBJudf.png
#
# Converted 0sYDNzwVMaWE2TIZeA81.bytes to byte_images\0sYDNzwVMaWE2TIZeA81.png
# Converted 19B6wSHOLmjhGPoquTbW.bytes to byte_images\19B6wSHOLmjhGPoquTbW.png
# Converted 19lTEvHhVDprkGxgXLcf.bytes to byte_images\19lTEvHhVDprkGxgXLcf.png
# Converted 1ARrSUKCbhWeTFyjp4ix.bytes to byte_images\1ARrSUKCbhWeTFyjp4ix.png
# Converted 1el4qZPVwIXavrChcyGp.bytes to byte_images\1el4qZPVwIXavrChcyGp.png
# Converted 1AXVt0D9mSU26fL4iFGc.bytes to byte_images\1AXVt0D9mSU26fL4iFGc.png
# Converted 1eOaAY4fpV38LIdhxl95.bytes to byte_images\1eOaAY4fpV38LIdhxl95.pngConverted 1buWc2A0VeMrkNpohCPy.bytes to byte_images\1buWc2A0VeMrkNpohCPy.png
#
# Converted 1ik3ncdBTYIJAgfmjpwz.bytes to byte_images\1ik3ncdBTYIJAgfmjpwz.png
# Converted 1h7nkscUw5lDurHXPE20.bytes to byte_images\1h7nkscUw5lDurHXPE20.png
# Converted 1eJx34l8pcAFvMuOwrjB.bytes to byte_images\1eJx34l8pcAFvMuOwrjB.pngConverted 1GRsOmJXetEkqIraBuSd.bytes to byte_images\1GRsOmJXetEkqIraBuSd.png
#
# Converted 1EisIfzGOTX8hKaFH6uy.bytes to byte_images\1EisIfzGOTX8hKaFH6uy.png
# Converted 1aAwe4J9VHrsq8uEoZhf.bytes to byte_images\1aAwe4J9VHrsq8uEoZhf.png
# Converted 1hK3zVxBGXmtTP6JlHwb.bytes to byte_images\1hK3zVxBGXmtTP6JlHwb.png
# Converted 1DNWriJEg56S03yvjTBu.bytes to byte_images\1DNWriJEg56S03yvjTBu.png
# Converted 148bgAqCj3NzaHwSP0Gu.bytes to byte_images\148bgAqCj3NzaHwSP0Gu.png
# Converted 1mStzMaQ8RUVBx7TkF4o.bytes to byte_images\1mStzMaQ8RUVBx7TkF4o.png
# Converted 1BDCxE2AMQN9yH6sWdIo.bytes to byte_images\1BDCxE2AMQN9yH6sWdIo.png
# Converted 1mlhNbQOFU0VtAP8ZJBk.bytes to byte_images\1mlhNbQOFU0VtAP8ZJBk.png
# Converted 1MjkqlJ7L6EoAPXb2fKV.bytes to byte_images\1MjkqlJ7L6EoAPXb2fKV.png
# Converted 1OHzGWXBTlpyVsIPK3kj.bytes to byte_images\1OHzGWXBTlpyVsIPK3kj.png
# Converted 1NvKF7pMREf4iVyzZewr.bytes to byte_images\1NvKF7pMREf4iVyzZewr.png
# Converted 1PQFYMSBLAO9TmKk2Zhj.bytes to byte_images\1PQFYMSBLAO9TmKk2Zhj.png
# Converted 1KjZ4An78sOytkzgRL0E.bytes to byte_images\1KjZ4An78sOytkzgRL0E.png
# Converted 1otbAhISV0yQ7vF6zndx.bytes to byte_images\1otbAhISV0yQ7vF6zndx.png
# Converted 1tzCLRxMuGS0yKI3lj8c.bytes to byte_images\1tzCLRxMuGS0yKI3lj8c.png
# Converted 1q92fF8uKHitWlaIkXzQ.bytes to byte_images\1q92fF8uKHitWlaIkXzQ.png
# Converted 1tBWqEHyDjQpKrGg5ulh.bytes to byte_images\1tBWqEHyDjQpKrGg5ulh.png
# Converted 1NiArstKkEmMf0vjDd7l.bytes to byte_images\1NiArstKkEmMf0vjDd7l.pngConverted 1TKPznCeQg9cHYflavwb.bytes to byte_images\1TKPznCeQg9cHYflavwb.png
#
# Converted 1T3m7BMCLXpu9JjyKH8R.bytes to byte_images\1T3m7BMCLXpu9JjyKH8R.png
# Converted 1KCvMqIFUoaB6wfOc2xQ.bytes to byte_images\1KCvMqIFUoaB6wfOc2xQ.png
# Converted 1Nu6CWGKlM4Xgi2x9a8H.bytes to byte_images\1Nu6CWGKlM4Xgi2x9a8H.png
# Converted 1Skcwz5YxWihMqIyt30X.bytes to byte_images\1Skcwz5YxWihMqIyt30X.png
# Converted 1L8Wt9XTV3pInwaqiobG.bytes to byte_images\1L8Wt9XTV3pInwaqiobG.png
# Converted 1zVtBw2rdTN9j7a4xZE0.bytes to byte_images\1zVtBw2rdTN9j7a4xZE0.png
# Converted 21l6VM9tKEuCUhL7DjeY.bytes to byte_images\21l6VM9tKEuCUhL7DjeY.png
# Converted 27V4S1ncC3fj0gitGuDI.bytes to byte_images\27V4S1ncC3fj0gitGuDI.png
# Converted 1yC7BzWHgtI2FibhQ0km.bytes to byte_images\1yC7BzWHgtI2FibhQ0km.png
# Converted 1uNTL24yHl3EVFidSzUA.bytes to byte_images\1uNTL24yHl3EVFidSzUA.png
# Converted 25JcvPNOIBXgSrAEtpUy.bytes to byte_images\25JcvPNOIBXgSrAEtpUy.png
# Converted 1Vd3xZnQl87fbhPoSYJ6.bytes to byte_images\1Vd3xZnQl87fbhPoSYJ6.png
# Converted 1rCGTyze8Mqbtx49fQOu.bytes to byte_images\1rCGTyze8Mqbtx49fQOu.png
# Converted 25jQ4xItcnbB6Hfo0E9T.bytes to byte_images\25jQ4xItcnbB6Hfo0E9T.png
# Converted 1YAFzJjOeKUCc7pubM9q.bytes to byte_images\1YAFzJjOeKUCc7pubM9q.png
# Converted 1vQKJIkiBaTVxc5uYCZW.bytes to byte_images\1vQKJIkiBaTVxc5uYCZW.png
# Converted 2AloO4fCXKL9DnYdeQUP.bytes to byte_images\2AloO4fCXKL9DnYdeQUP.png
# Converted 2cf8jvWxmkMu6s10zbqN.bytes to byte_images\2cf8jvWxmkMu6s10zbqN.png
# Converted 2eJq8SOvi1Bs4T9XNEj6.bytes to byte_images\2eJq8SOvi1Bs4T9XNEj6.png
# Converted 2e5P1iKzXugGRBFfOEnc.bytes to byte_images\2e5P1iKzXugGRBFfOEnc.png
# Converted 2F5DOMVLNGfQKePHdwru.bytes to byte_images\2F5DOMVLNGfQKePHdwru.png
# Converted 2eqnSQrGfCXupwkDtIJ6.bytes to byte_images\2eqnSQrGfCXupwkDtIJ6.png
# Converted 29FZvBJyX0GbnaLAYeKw.bytes to byte_images\29FZvBJyX0GbnaLAYeKw.png
# Converted 2HRQ1j0Dx3fv8Ad7n9rg.bytes to byte_images\2HRQ1j0Dx3fv8Ad7n9rg.png
# Converted 2jHV3wyk5aDGBs9SFCvW.bytes to byte_images\2jHV3wyk5aDGBs9SFCvW.png
# Converted 2gwSoct3BzRUvajVeCLu.bytes to byte_images\2gwSoct3BzRUvajVeCLu.png
# Converted 2bf65CdkZTUGXjzq9KNJ.bytes to byte_images\2bf65CdkZTUGXjzq9KNJ.png
# Converted 2FfmJdWv6RrIjzYhaKZ1.bytes to byte_images\2FfmJdWv6RrIjzYhaKZ1.png
# Converted 2LR1cT43f809ZG6KUd5l.bytes to byte_images\2LR1cT43f809ZG6KUd5l.png
# Converted 2LEOmN89p57jGayvcXet.bytes to byte_images\2LEOmN89p57jGayvcXet.png
# Converted 2nr0GTSxN4zKobZqwpy6.bytes to byte_images\2nr0GTSxN4zKobZqwpy6.png
# Converted 2EgZDWKnJV3Gz4TkIiYU.bytes to byte_images\2EgZDWKnJV3Gz4TkIiYU.png
# Converted 2DbfJX4WgzP0R8BwrHyS.bytes to byte_images\2DbfJX4WgzP0R8BwrHyS.png
# Converted 2ECqL8au6iS3jNJDoOdn.bytes to byte_images\2ECqL8au6iS3jNJDoOdn.png
# Converted 2gMFLJAaNEkx7oWRwl54.bytes to byte_images\2gMFLJAaNEkx7oWRwl54.png
# Converted 2oyTpmYF4tSuBH9kXQc7.bytes to byte_images\2oyTpmYF4tSuBH9kXQc7.png
# Converted 2L8T9IgSrJs7mlF5PueZ.bytes to byte_images\2L8T9IgSrJs7mlF5PueZ.png
# Converted 2EkHfwNj5o7JcDq6UzuG.bytes to byte_images\2EkHfwNj5o7JcDq6UzuG.png
# Converted 2OZkNTqAJ8X61eK4pjhR.bytes to byte_images\2OZkNTqAJ8X61eK4pjhR.png
# Converted 2mZqzjspRt5Xy4B9f03L.bytes to byte_images\2mZqzjspRt5Xy4B9f03L.png
# Converted 2qSURceVYgQEhOFAdPXC.bytes to byte_images\2qSURceVYgQEhOFAdPXC.png
# Converted 2SnRYbpqifxILdT4Wg9m.bytes to byte_images\2SnRYbpqifxILdT4Wg9m.png
# Converted 2oMjFb1UfIym9ZgxDPqG.bytes to byte_images\2oMjFb1UfIym9ZgxDPqG.png
# Converted 2vzlFiPL03STnwtDhoCU.bytes to byte_images\2vzlFiPL03STnwtDhoCU.png
# Converted 2WkGMV9mKJrBAOZL5zdI.bytes to byte_images\2WkGMV9mKJrBAOZL5zdI.png
# Converted 2NakDPd4GWEwzuHhTx5o.bytes to byte_images\2NakDPd4GWEwzuHhTx5o.png
# Converted 2RsBPMStVQNc7x3kgYde.bytes to byte_images\2RsBPMStVQNc7x3kgYde.png
# Converted 2xlhAE5LO8RFfczB6ep3.bytes to byte_images\2xlhAE5LO8RFfczB6ep3.png
# Converted 30htxi8FRcmfUkInewlS.bytes to byte_images\30htxi8FRcmfUkInewlS.png
# Converted 2kjJp4LQZsyxwquaB7WA.bytes to byte_images\2kjJp4LQZsyxwquaB7WA.png
# Converted 2X3tMeVL1QZ4WJmdqkUz.bytes to byte_images\2X3tMeVL1QZ4WJmdqkUz.png
# Converted 2ZPDI3tv7UdhkfRWu54L.bytes to byte_images\2ZPDI3tv7UdhkfRWu54L.png
# Converted 2NYAUVgtXPpbJzRQO7Cl.bytes to byte_images\2NYAUVgtXPpbJzRQO7Cl.png
# Converted 2r0UYLcKCxnRovpj5dlQ.bytes to byte_images\2r0UYLcKCxnRovpj5dlQ.png
# Converted 32rcXoa5QI1EmxBFS9he.bytes to byte_images\32rcXoa5QI1EmxBFS9he.png
# Converted 2ZY5e4PHsEAvkziQGFR6.bytes to byte_images\2ZY5e4PHsEAvkziQGFR6.png
# Converted 2SRWXLQomgJyliq3G6BM.bytes to byte_images\2SRWXLQomgJyliq3G6BM.png
# Converted 2qZrQoxyYDeadjIp3mSH.bytes to byte_images\2qZrQoxyYDeadjIp3mSH.png
# Converted 37MUhjJKBdCYFZyvqHWu.bytes to byte_images\37MUhjJKBdCYFZyvqHWu.png
# Converted 2O8w7LMDfCgRhnvNuetV.bytes to byte_images\2O8w7LMDfCgRhnvNuetV.png
# Converted 2zUdQEyv5oKARaYGxhXk.bytes to byte_images\2zUdQEyv5oKARaYGxhXk.png
# Converted 2YNFrzjaecyUInXCDVmt.bytes to byte_images\2YNFrzjaecyUInXCDVmt.png
# Converted 39YX8jkenM2UHOvCRDq5.bytes to byte_images\39YX8jkenM2UHOvCRDq5.png
# Converted 3afO9NUdwDyT6IlAm7gk.bytes to byte_images\3afO9NUdwDyT6IlAm7gk.png
# Converted 35dbDR8KSIwZNAPlcgTi.bytes to byte_images\35dbDR8KSIwZNAPlcgTi.png
# Converted 36mPaSFkA7gVLnCbhqTt.bytes to byte_images\36mPaSFkA7gVLnCbhqTt.png
# Converted 3Cb9mdkictPwsSOTKUIY.bytes to byte_images\3Cb9mdkictPwsSOTKUIY.png
# Converted 35B8Vh0Q9k4STsiCtKx2.bytes to byte_images\35B8Vh0Q9k4STsiCtKx2.png
# Converted 39gowdFUK2kGxcBnbALH.bytes to byte_images\39gowdFUK2kGxcBnbALH.png
# Converted 32r6nRhN1UCwtFTfy8ZG.bytes to byte_images\32r6nRhN1UCwtFTfy8ZG.png
# Converted 387RdPoyKxJIZr1YNcO6.bytes to byte_images\387RdPoyKxJIZr1YNcO6.png
# Converted 3eaqPVnAvws1lHzX9GhD.bytes to byte_images\3eaqPVnAvws1lHzX9GhD.png
# Converted 3Bsqe5aIEWKZvOjXmox9.bytes to byte_images\3Bsqe5aIEWKZvOjXmox9.png
# Converted 3cLxp0USf758FCdWIMeb.bytes to byte_images\3cLxp0USf758FCdWIMeb.png
# Converted 37Og0blzE4WYpZ5c9LMN.bytes to byte_images\37Og0blzE4WYpZ5c9LMN.png
# Converted 3Ce9LP6ngx2uBtSyczRG.bytes to byte_images\3Ce9LP6ngx2uBtSyczRG.png
# Converted 3IZHa2xXVu6KrgNoPd9W.bytes to byte_images\3IZHa2xXVu6KrgNoPd9W.png
# Converted 3aisrYOcQetkUqnfvp5K.bytes to byte_images\3aisrYOcQetkUqnfvp5K.png
# Converted 3FNOSAujbRIDnZqhmeMo.bytes to byte_images\3FNOSAujbRIDnZqhmeMo.png
# Converted 3lVFreCQGTEnZyYs1Iiz.bytes to byte_images\3lVFreCQGTEnZyYs1Iiz.png
# Converted 3eHwdBolFKi4PahtXSyg.bytes to byte_images\3eHwdBolFKi4PahtXSyg.png
# Converted 3g7SToXfidhHqjZ5RJUb.bytes to byte_images\3g7SToXfidhHqjZ5RJUb.png
# Converted 3MZriOFjTzUcpWfl4nah.bytes to byte_images\3MZriOFjTzUcpWfl4nah.png
# Converted 3eNs5FMHf1IcySgw6QG2.bytes to byte_images\3eNs5FMHf1IcySgw6QG2.png
# Converted 3kpwYGsKyF8HlnjDm6aA.bytes to byte_images\3kpwYGsKyF8HlnjDm6aA.png
# Converted 3OX0rbks7LQmeDcKx8C4.bytes to byte_images\3OX0rbks7LQmeDcKx8C4.png
# Converted 3PUsV4jflnCw8mGHZIgK.bytes to byte_images\3PUsV4jflnCw8mGHZIgK.png
# Converted 3d2x0BYR7aiJLfPNsbgo.bytes to byte_images\3d2x0BYR7aiJLfPNsbgo.png
# Converted 3RiBw0ntobeCh5VEQrY1.bytes to byte_images\3RiBw0ntobeCh5VEQrY1.png
# Converted 3LOYzcPQdE7yresjlXVm.bytes to byte_images\3LOYzcPQdE7yresjlXVm.png
# Converted 3mpsxg2FODqCAXHbMKPi.bytes to byte_images\3mpsxg2FODqCAXHbMKPi.png
# Converted 3Rpwdu5AN4l2KkeoYHED.bytes to byte_images\3Rpwdu5AN4l2KkeoYHED.png
# Converted 3pU5vISM0d7gtEi6wFXr.bytes to byte_images\3pU5vISM0d7gtEi6wFXr.png
# Converted 3nqel6RATDmiaQJwpZCz.bytes to byte_images\3nqel6RATDmiaQJwpZCz.png
# Converted 3nxujXtip8hGHb6ZQdA4.bytes to byte_images\3nxujXtip8hGHb6ZQdA4.png
# Converted 3b7cK2nPtTHIQ658wsYk.bytes to byte_images\3b7cK2nPtTHIQ658wsYk.png
# Converted 3cG5wXTa8pRN7ObFtE4K.bytes to byte_images\3cG5wXTa8pRN7ObFtE4K.png
# Converted 3Wi8BgsVyjH7oKbEPq9f.bytes to byte_images\3Wi8BgsVyjH7oKbEPq9f.png
# Converted 3X2nY7iQaPBIWDrAZqJe.bytes to byte_images\3X2nY7iQaPBIWDrAZqJe.png
# Converted 3wauD2jYkTUn7izLcvV8.bytes to byte_images\3wauD2jYkTUn7izLcvV8.png
# Converted 3xhmsIkdn7FPL4G9a0Qg.bytes to byte_images\3xhmsIkdn7FPL4G9a0Qg.png
# Converted 3yPmbIvrqGOeWRSUnFTA.bytes to byte_images\3yPmbIvrqGOeWRSUnFTA.png
# Converted 3yALVj1gQbw6HfK4WMvl.bytes to byte_images\3yALVj1gQbw6HfK4WMvl.png
# Converted 41sxuO3ZpR5vAc0Kbjqe.bytes to byte_images\41sxuO3ZpR5vAc0Kbjqe.png
# Converted 41o3zDTReYVFtpOB7EWl.bytes to byte_images\41o3zDTReYVFtpOB7EWl.png
# Converted 3X2jQ6SzeKCxA7WmlqoZ.bytes to byte_images\3X2jQ6SzeKCxA7WmlqoZ.png
# Converted 40dBpWDhOUzZ5yVAKJF3.bytes to byte_images\40dBpWDhOUzZ5yVAKJF3.png
# Converted 3vG9FbUS2P8Xcfsj4WLw.bytes to byte_images\3vG9FbUS2P8Xcfsj4WLw.png
# Converted 3WPEFKHwX1DLBI4bzAM7.bytes to byte_images\3WPEFKHwX1DLBI4bzAM7.png
# Converted 3rsuE2CHA4WG16fQynUK.bytes to byte_images\3rsuE2CHA4WG16fQynUK.png
# Converted 496EYbjny1LlaK3sr5Zu.bytes to byte_images\496EYbjny1LlaK3sr5Zu.png
# Converted 3x9R8E6Gv5JhDda2eoq4.bytes to byte_images\3x9R8E6Gv5JhDda2eoq4.png
# Converted 3RrCi87ovZ1Qw6WuygGB.bytes to byte_images\3RrCi87ovZ1Qw6WuygGB.png
# Converted 3TDhUPRqnKiQ8VpB6oCY.bytes to byte_images\3TDhUPRqnKiQ8VpB6oCY.png
# Converted 3yitlJFLwPhTcNbUA2aS.bytes to byte_images\3yitlJFLwPhTcNbUA2aS.png
# Converted 49epoGtYixcgnkfwJ2dv.bytes to byte_images\49epoGtYixcgnkfwJ2dv.png
# Converted 4bEmQThjKsiSPcFfzv1q.bytes to byte_images\4bEmQThjKsiSPcFfzv1q.png
# Converted 4AuqM30HyOajgr8SleRL.bytes to byte_images\4AuqM30HyOajgr8SleRL.png
# Converted 4c3h7j0QyqIgnKFzA5vR.bytes to byte_images\4c3h7j0QyqIgnKFzA5vR.png
# Converted 4FdKAHtfpGS1hCjgyNJo.bytes to byte_images\4FdKAHtfpGS1hCjgyNJo.png
# Converted 4EB7To6p1z8FAQekCjZi.bytes to byte_images\4EB7To6p1z8FAQekCjZi.png
# Converted 4f91UESFtRDrnLdyZOCN.bytes to byte_images\4f91UESFtRDrnLdyZOCN.png
# Converted 4augeM3l7UKbHc6ITnOL.bytes to byte_images\4augeM3l7UKbHc6ITnOL.png
# Converted 49RfyxpQP1CzvneWIG5q.bytes to byte_images\49RfyxpQP1CzvneWIG5q.png
# Converted 4JGbOVQnEt3ZP5acW7Yz.bytes to byte_images\4JGbOVQnEt3ZP5acW7Yz.png
# Converted 4dgyhKqaZbAvwx2eXFsc.bytes to byte_images\4dgyhKqaZbAvwx2eXFsc.png
# Converted 4dYWHLCBPVg5xTAzRK0e.bytes to byte_images\4dYWHLCBPVg5xTAzRK0e.png
# Converted 4fYojiJ3XwcILTA6KlWu.bytes to byte_images\4fYojiJ3XwcILTA6KlWu.png
# Converted 4Eo8QvuZFWCBR6i0rhs7.bytes to byte_images\4Eo8QvuZFWCBR6i0rhs7.png
# Converted 4GUJ7HBXO8I56WyRSMQd.bytes to byte_images\4GUJ7HBXO8I56WyRSMQd.png
# Converted 4Mt53c8yqLWdVzrUoFOP.bytes to byte_images\4Mt53c8yqLWdVzrUoFOP.png
# Converted 4InZfrkMYP8UQOaevoK0.bytes to byte_images\4InZfrkMYP8UQOaevoK0.png
# Converted 4kuxDJlwWHMi5KX3SVQq.bytes to byte_images\4kuxDJlwWHMi5KX3SVQq.png
# Converted 4CLQnNRbyBDWOaIMFog7.bytes to byte_images\4CLQnNRbyBDWOaIMFog7.png
# Converted 4jNUtkx1QJrzdo2ZqB6K.bytes to byte_images\4jNUtkx1QJrzdo2ZqB6K.png
# Converted 4OfNIyw7BxlzSHWEi3mL.bytes to byte_images\4OfNIyw7BxlzSHWEi3mL.png
# Converted 4iD1ec9BR6Mghzm82yqs.bytes to byte_images\4iD1ec9BR6Mghzm82yqs.png
# Converted 4S1uOdNGqKkCxZFVWAzB.bytes to byte_images\4S1uOdNGqKkCxZFVWAzB.png
# Converted 4omjpRdNPCMSfxi3TyEA.bytes to byte_images\4omjpRdNPCMSfxi3TyEA.png
# Converted 4QCBDTJFskOqox0H8XIL.bytes to byte_images\4QCBDTJFskOqox0H8XIL.png
# Converted 4Nxt0uDWz8f6YpPqCTM5.bytes to byte_images\4Nxt0uDWz8f6YpPqCTM5.png
# Converted 4n5LKPoBHSyfNz6iWJeQ.bytes to byte_images\4n5LKPoBHSyfNz6iWJeQ.png
# Converted 4nEqldNaweD7j806tbhk.bytes to byte_images\4nEqldNaweD7j806tbhk.png
# Converted 4WaGm3PhidQVRopgXz7J.bytes to byte_images\4WaGm3PhidQVRopgXz7J.png
# Converted 4ng9zuri2Dtm5H8INwxF.bytes to byte_images\4ng9zuri2Dtm5H8INwxF.png
# Converted 4Qcv9hWIsmBX3PUNLltT.bytes to byte_images\4Qcv9hWIsmBX3PUNLltT.png
# Converted 4jVLlkxAIGvb3MBzDYHc.bytes to byte_images\4jVLlkxAIGvb3MBzDYHc.png
# Converted 4suKxkVWNqFQZLB5UfXD.bytes to byte_images\4suKxkVWNqFQZLB5UfXD.png
# Converted 4RKTW3jA6pyNbV2lgUst.bytes to byte_images\4RKTW3jA6pyNbV2lgUst.png
# Converted 4NnkJueQdl9yX7ITwZKY.bytes to byte_images\4NnkJueQdl9yX7ITwZKY.png
# Converted 4XAPr8eSwWqzUlc739ZY.bytes to byte_images\4XAPr8eSwWqzUlc739ZY.png
# Converted 4XEdp5nArx9TN3qZ62kf.bytes to byte_images\4XEdp5nArx9TN3qZ62kf.png
# Converted 4wvKaeRqlQSBEP9nLOMI.bytes to byte_images\4wvKaeRqlQSBEP9nLOMI.png
# Converted 4wrp1jESmXKUAvH5s2aR.bytes to byte_images\4wrp1jESmXKUAvH5s2aR.png
# Converted 5102w8Hp4TRkWbIUXSgZ.bytes to byte_images\5102w8Hp4TRkWbIUXSgZ.png
# Converted 508Uk9z1gvCtucARFWG3.bytes to byte_images\508Uk9z1gvCtucARFWG3.png
# Converted 4wv86XGCOkUWEAPrJtDi.bytes to byte_images\4wv86XGCOkUWEAPrJtDi.png
# Converted 56KhNHUTXZpryYaGqoj4.bytes to byte_images\56KhNHUTXZpryYaGqoj4.png
# Converted 4wIxhDlpCbJVkZLfHKtP.bytes to byte_images\4wIxhDlpCbJVkZLfHKtP.png
# Converted 50f7jCS4w3hED2ueRosN.bytes to byte_images\50f7jCS4w3hED2ueRosN.png
# Converted 57aolZC6XSxqr2HiGsfV.bytes to byte_images\57aolZC6XSxqr2HiGsfV.png
# Converted 59P7Kv8cMforuZUpVQnY.bytes to byte_images\59P7Kv8cMforuZUpVQnY.png
# Converted 51qVyQZvcFaz89onAOBS.bytes to byte_images\51qVyQZvcFaz89onAOBS.png
# Converted 51NK2bWwuvf6rH7RTCPk.bytes to byte_images\51NK2bWwuvf6rH7RTCPk.png
# Converted 4zB07s1G3KjqYibEO5J2.bytes to byte_images\4zB07s1G3KjqYibEO5J2.png
# Converted 5dqijn0zcEPgONTLFRoI.bytes to byte_images\5dqijn0zcEPgONTLFRoI.png
# Converted 50iq3CaS7H1PDWetAMLR.bytes to byte_images\50iq3CaS7H1PDWetAMLR.png
# Converted 5CQsuk3ygnTmHKEBDbzZ.bytes to byte_images\5CQsuk3ygnTmHKEBDbzZ.png
# Converted 4vr2yUw5PiEgN6BaWRho.bytes to byte_images\4vr2yUw5PiEgN6BaWRho.png
# Converted 5aqZV2vfkm63IeXYPlWg.bytes to byte_images\5aqZV2vfkm63IeXYPlWg.png
# Converted 5gVwWXsxtIzEn6RUJq7G.bytes to byte_images\5gVwWXsxtIzEn6RUJq7G.png
# Converted 5iJsI0VCgF2D1Gukdayc.bytes to byte_images\5iJsI0VCgF2D1Gukdayc.png
# Converted 5Kj6AhNFgwEU9aeCXTOy.bytes to byte_images\5Kj6AhNFgwEU9aeCXTOy.png
# Converted 5i3dyOv9GDKJuCVHF0q1.bytes to byte_images\5i3dyOv9GDKJuCVHF0q1.png
# Converted 5AycfmLjIp7NnvgS1JYW.bytes to byte_images\5AycfmLjIp7NnvgS1JYW.png
# Converted 5JfdLYbqX8oFmD1WTg97.bytes to byte_images\5JfdLYbqX8oFmD1WTg97.png
# Converted 5nPbr70kNiOSQGZmL8IH.bytes to byte_images\5nPbr70kNiOSQGZmL8IH.png
# Converted 5a8pEcRyqVKFmYnGsTrb.bytes to byte_images\5a8pEcRyqVKFmYnGsTrb.png
# Converted 5MjiBxhL0nSvV9CUedQI.bytes to byte_images\5MjiBxhL0nSvV9CUedQI.png
# Converted 5fcdwygv9TKrl3GW0zMA.bytes to byte_images\5fcdwygv9TKrl3GW0zMA.png
# Converted 5FyHhsqWCcxTkAS7wVlD.bytes to byte_images\5FyHhsqWCcxTkAS7wVlD.png
# Converted 4xPwVZd8CpJEAUIebmvB.bytes to byte_images\4xPwVZd8CpJEAUIebmvB.png
# Converted 5sLXK39w4fkSzAVi1Q6U.bytes to byte_images\5sLXK39w4fkSzAVi1Q6U.png
# Converted 5PBvwNE8sCzm1bjUlf6A.bytes to byte_images\5PBvwNE8sCzm1bjUlf6A.png
# Converted 5qQY8mHGLFA1pZgWPOXM.bytes to byte_images\5qQY8mHGLFA1pZgWPOXM.png
# Converted 5R3hLjKfZMi8mYI2zVwb.bytes to byte_images\5R3hLjKfZMi8mYI2zVwb.png
# Converted 5W4u3pSRyDefEKhVNZms.bytes to byte_images\5W4u3pSRyDefEKhVNZms.png
# Converted 5jkOh9VRtDcMElf1TUBo.bytes to byte_images\5jkOh9VRtDcMElf1TUBo.png
# Converted 5QvCJULkphcYGge78RNs.bytes to byte_images\5QvCJULkphcYGge78RNs.png
# Converted 5QjzywcSG4XLhNRt8unq.bytes to byte_images\5QjzywcSG4XLhNRt8unq.png
# Converted 5scq0VdirPRF8DxUKbh1.bytes to byte_images\5scq0VdirPRF8DxUKbh1.png
# Converted 5bNgRzHpdGInuxjQBvFt.bytes to byte_images\5bNgRzHpdGInuxjQBvFt.png
# Converted 5PIwjdM6ROvnbiN9Dx0a.bytes to byte_images\5PIwjdM6ROvnbiN9Dx0a.png
# Converted 5NMDYGWr4mKFTIk1fQUH.bytes to byte_images\5NMDYGWr4mKFTIk1fQUH.png
# Converted 5yeOrl2fKasq6BnStQ4G.bytes to byte_images\5yeOrl2fKasq6BnStQ4G.png
# Converted 60q1Io2usSnJWyNpzDlA.bytes to byte_images\60q1Io2usSnJWyNpzDlA.png
# Converted 5YhH9bwB2VyoukplmOQA.bytes to byte_images\5YhH9bwB2VyoukplmOQA.png
# Converted 5YcQadwmPLqg72tvW8iS.bytes to byte_images\5YcQadwmPLqg72tvW8iS.png
# Converted 61ZG4u8AIUrOMNRYf0sC.bytes to byte_images\61ZG4u8AIUrOMNRYf0sC.png
# Converted 65cjJpPCUQiLDRyXfWd4.bytes to byte_images\65cjJpPCUQiLDRyXfWd4.png
# Converted 5XPfYvNdQRIBJoWmj3Os.bytes to byte_images\5XPfYvNdQRIBJoWmj3Os.png
# Converted 69jsYQMcGwzrBLUPRb5e.bytes to byte_images\69jsYQMcGwzrBLUPRb5e.png
# Converted 63vS2seA0bRQhG4fugWE.bytes to byte_images\63vS2seA0bRQhG4fugWE.png
# Converted 67LFYMBVhdD3Jo2UGRSX.bytes to byte_images\67LFYMBVhdD3Jo2UGRSX.png
# Converted 5xzWZR1OXkKjBTtPYVai.bytes to byte_images\5xzWZR1OXkKjBTtPYVai.png
# Converted 6aTHENeI5PBYgzJndM7V.bytes to byte_images\6aTHENeI5PBYgzJndM7V.png
# Converted 60C4Kupa7OAXWcjTQIqy.bytes to byte_images\60C4Kupa7OAXWcjTQIqy.png
# Converted 6B17gNAqEZiQyvt8FDP3.bytes to byte_images\6B17gNAqEZiQyvt8FDP3.png
# Converted 5zYVF03NXadb7Gv64PqC.bytes to byte_images\5zYVF03NXadb7Gv64PqC.png
# Converted 6bqeRU05pPKuGxQ7NEkO.bytes to byte_images\6bqeRU05pPKuGxQ7NEkO.png
# Converted 5Xc0iAYjsG7ugxrZNIoS.bytes to byte_images\5Xc0iAYjsG7ugxrZNIoS.png
# Converted 697TFDm0KRiZIgB4pJG1.bytes to byte_images\697TFDm0KRiZIgB4pJG1.png
# Converted 602shC5njSE4yHNZ3QFM.bytes to byte_images\602shC5njSE4yHNZ3QFM.png
# Converted 69MHIoldGcUTvxEOXJyw.bytes to byte_images\69MHIoldGcUTvxEOXJyw.png
# Converted 6CsTIZDSEdqNzi5tOKBo.bytes to byte_images\6CsTIZDSEdqNzi5tOKBo.png
# Converted 6cJ4OV1TGifn92SCPNEA.bytes to byte_images\6cJ4OV1TGifn92SCPNEA.png
# Converted 6JckVCSUd5azvlGjBtbu.bytes to byte_images\6JckVCSUd5azvlGjBtbu.png
# Converted 6CbnMfItA5py0odwQjPR.bytes to byte_images\6CbnMfItA5py0odwQjPR.png
# Converted 6cYUST29aReytkJO4zXi.bytes to byte_images\6cYUST29aReytkJO4zXi.png
# Converted 6HdwDkgvEnNh9cqlyfR7.bytes to byte_images\6HdwDkgvEnNh9cqlyfR7.png
# Converted 6gHI9qzDjmLhd4nWS3oi.bytes to byte_images\6gHI9qzDjmLhd4nWS3oi.png
# Converted 6DBKSix3qaP1HcQ8r7uG.bytes to byte_images\6DBKSix3qaP1HcQ8r7uG.png
# Converted 6Ep5PZ3J09edDNo4ahx8.bytes to byte_images\6Ep5PZ3J09edDNo4ahx8.png
# Converted 6a9QCg870OIZxrEmqK2l.bytes to byte_images\6a9QCg870OIZxrEmqK2l.png
# Converted 6cylqphx5sHCm4fYBEdK.bytes to byte_images\6cylqphx5sHCm4fYBEdK.png
# Converted 6GbjZn4wEtWSkrJUzoVc.bytes to byte_images\6GbjZn4wEtWSkrJUzoVc.png
# Converted 6Ij39ZnpNmcdKOUe0BvY.bytes to byte_images\6Ij39ZnpNmcdKOUe0BvY.png
# Converted 6MfjO3CBFGpvi2mWzwkV.bytes to byte_images\6MfjO3CBFGpvi2mWzwkV.png
# Converted 6jCs7bHULZXW3kKtxNRw.bytes to byte_images\6jCs7bHULZXW3kKtxNRw.png
# Converted 6pvAOQCLGgPa1EKniNW0.bytes to byte_images\6pvAOQCLGgPa1EKniNW0.png
# Converted 6qU3wkD1pLx42PcgMFEO.bytes to byte_images\6qU3wkD1pLx42PcgMFEO.png
# Converted 6JcOPhsUjbfXgnoQaHyN.bytes to byte_images\6JcOPhsUjbfXgnoQaHyN.png
# Converted 6p0xPcyrDB4R8YNHEsnU.bytes to byte_images\6p0xPcyrDB4R8YNHEsnU.png
# Converted 6qx5KcpelROjwUVJS01I.bytes to byte_images\6qx5KcpelROjwUVJS01I.png
# Converted 6NH7fncljqxP30hOriSw.bytes to byte_images\6NH7fncljqxP30hOriSw.png
# Converted 6KauYyxGt1n8wViqbe5X.bytes to byte_images\6KauYyxGt1n8wViqbe5X.png
# Converted 6sSpDfKNmx3R4rjQeW9M.bytes to byte_images\6sSpDfKNmx3R4rjQeW9M.png
# Converted 6OaQhmCAoK3e8qH7NrB5.bytes to byte_images\6OaQhmCAoK3e8qH7NrB5.png
# Converted 6SHqMnAlwd79OrYL50Ti.bytes to byte_images\6SHqMnAlwd79OrYL50Ti.png
# Converted 6McvAWZj4285L7XPrwnE.bytes to byte_images\6McvAWZj4285L7XPrwnE.png
# Converted 6NCw8nF9A7fUzYLyJIiD.bytes to byte_images\6NCw8nF9A7fUzYLyJIiD.png
# Converted 6slf2AGqxWCP53Z9NuhI.bytes to byte_images\6slf2AGqxWCP53Z9NuhI.png
# Converted 6r02dN7YEojsfTQkzlGh.bytes to byte_images\6r02dN7YEojsfTQkzlGh.png
# Converted 6mKG5UgpFBOYCdR3Wz8J.bytes to byte_images\6mKG5UgpFBOYCdR3Wz8J.png
# Converted 6u25JYNBy8wzSHUjqxvh.bytes to byte_images\6u25JYNBy8wzSHUjqxvh.png
# Converted 6rH4RophlktZL3Cwefbu.bytes to byte_images\6rH4RophlktZL3Cwefbu.png
# Converted 6qjSVHW1IFQOTALiRzca.bytes to byte_images\6qjSVHW1IFQOTALiRzca.png
# Converted 6wHyQ3DVLMBtsxnhGvmo.bytes to byte_images\6wHyQ3DVLMBtsxnhGvmo.png
# Converted 6WDhbdurpOMFTsP8XkUm.bytes to byte_images\6WDhbdurpOMFTsP8XkUm.png
# Converted 6v3P0dtFROb2kyiNrKQ1.bytes to byte_images\6v3P0dtFROb2kyiNrKQ1.png
# Converted 6JOiKa5LrAtu42TpY7kI.bytes to byte_images\6JOiKa5LrAtu42TpY7kI.png
# Converted 6ZY9Al0hSbQBGF1RcLVH.bytes to byte_images\6ZY9Al0hSbQBGF1RcLVH.png
# Converted 6ZdpisIvCL1GornaSU4D.bytes to byte_images\6ZdpisIvCL1GornaSU4D.png
# Converted 6WKbReFUk18wYnCNQsyH.bytes to byte_images\6WKbReFUk18wYnCNQsyH.png
# Converted 6z8BRNc5EJetqCs4kZYl.bytes to byte_images\6z8BRNc5EJetqCs4kZYl.png
# Converted 723C8e4nNUKMLrQZYdpP.bytes to byte_images\723C8e4nNUKMLrQZYdpP.png
# Converted 7brc10uy63I9lxBGkJD8.bytes to byte_images\7brc10uy63I9lxBGkJD8.png
# Converted 7AJMbxOIN3YyFnjg5oDR.bytes to byte_images\7AJMbxOIN3YyFnjg5oDR.png
# Converted 6w02fn5UqNDMd1tISWKc.bytes to byte_images\6w02fn5UqNDMd1tISWKc.png
# Converted 7c06VofO9jp8dkSIunga.bytes to byte_images\7c06VofO9jp8dkSIunga.png
# Converted 7D92cJaF5QIdpA1OEhSt.bytes to byte_images\7D92cJaF5QIdpA1OEhSt.png
# Converted 75qSAohLWYb60Hs24NUF.bytes to byte_images\75qSAohLWYb60Hs24NUF.png
# Converted 7aEbXfVnzhG6dRMLT58q.bytes to byte_images\7aEbXfVnzhG6dRMLT58q.png
# Converted 78LEYtRhNmAP9Oogdv2Q.bytes to byte_images\78LEYtRhNmAP9Oogdv2Q.png
# Converted 7GsWJqlM3kCt62axD5O8.bytes to byte_images\7GsWJqlM3kCt62axD5O8.png
# Converted 6TUw1J5DR47dAgmjHLOs.bytes to byte_images\6TUw1J5DR47dAgmjHLOs.png
# Converted 76cGRgDJyFW08rY1tz59.bytes to byte_images\76cGRgDJyFW08rY1tz59.pngConverted 7a5RVl9htyOJcBUK4rQm.bytes to byte_images\7a5RVl9htyOJcBUK4rQm.png
#
# Converted 7cx4QdBWg9wMa2pvOLuo.bytes to byte_images\7cx4QdBWg9wMa2pvOLuo.png
# Converted 73LO4S6We2aGQvM0qCXo.bytes to byte_images\73LO4S6We2aGQvM0qCXo.png
# Converted 7IrpXlvH6LOStVaewBPg.bytes to byte_images\7IrpXlvH6LOStVaewBPg.png
# Converted 7DU2vQMzELbKx3tBjg9O.bytes to byte_images\7DU2vQMzELbKx3tBjg9O.png
# Converted 7IpfdG8WOkLFojV5bwJr.bytes to byte_images\7IpfdG8WOkLFojV5bwJr.png
# Converted 7l4AkQw3Gx8XRcJO1gaK.bytes to byte_images\7l4AkQw3Gx8XRcJO1gaK.png
# Converted 6v4lNabkVg0pe15nLshu.bytes to byte_images\6v4lNabkVg0pe15nLshu.png
# Converted 7iBwyZQ5kxGEjPN9fThM.bytes to byte_images\7iBwyZQ5kxGEjPN9fThM.png
# Converted 7dW2EIJqY86gKjPbtCkw.bytes to byte_images\7dW2EIJqY86gKjPbtCkw.png
# Converted 7KVtWPn30iJpvBkIej4o.bytes to byte_images\7KVtWPn30iJpvBkIej4o.pngConverted 7eicxTZ3pDPf65O1RLXg.bytes to byte_images\7eicxTZ3pDPf65O1RLXg.png
#
# Converted 7KqfVlEBOmr6tTQewNG8.bytes to byte_images\7KqfVlEBOmr6tTQewNG8.png
# Converted 7o5WIv30JPjRy1LHQbGq.bytes to byte_images\7o5WIv30JPjRy1LHQbGq.png
# Converted 7lYJNX4TjapibMyvd9sz.bytes to byte_images\7lYJNX4TjapibMyvd9sz.png
# Converted 7h32P6rADjMVEQuoOJIB.bytes to byte_images\7h32P6rADjMVEQuoOJIB.png
# Converted 7ptdL0VO1BzPlWXnGHwJ.bytes to byte_images\7ptdL0VO1BzPlWXnGHwJ.png
# Converted 7Ounj5D9ZaJBSbK0iodY.bytes to byte_images\7Ounj5D9ZaJBSbK0iodY.png
# Converted 7oMbW9DCm6tQn5FTRIus.bytes to byte_images\7oMbW9DCm6tQn5FTRIus.png
# Converted 7JjQBd2CAyvtgYlSL0e3.bytes to byte_images\7JjQBd2CAyvtgYlSL0e3.png
# Converted 7QrNYCk9O18JlZWgxmwE.bytes to byte_images\7QrNYCk9O18JlZWgxmwE.png
# Converted 7oKB6OiGX8LStVwnqlQI.bytes to byte_images\7oKB6OiGX8LStVwnqlQI.png
# Converted 7iEfJHXeGdvRDhx364nL.bytes to byte_images\7iEfJHXeGdvRDhx364nL.png
# Converted 7schXvl2FHSujB3aVK9e.bytes to byte_images\7schXvl2FHSujB3aVK9e.png
# Converted 7RVrih9gAL1FodIKNTc2.bytes to byte_images\7RVrih9gAL1FodIKNTc2.png
# Converted 7r4nyOFDRwkc2EgxopWV.bytes to byte_images\7r4nyOFDRwkc2EgxopWV.png
# Converted 7iQNYb2mIPzy354RMLX6.bytes to byte_images\7iQNYb2mIPzy354RMLX6.png
# Converted 7Rx5kEXu8PUcAvqodymC.bytes to byte_images\7Rx5kEXu8PUcAvqodymC.png
# Converted 7QtHrPMIOSsxAde6wnv0.bytes to byte_images\7QtHrPMIOSsxAde6wnv0.png
# Converted 7rneDC6Ng10vEPuicRWV.bytes to byte_images\7rneDC6Ng10vEPuicRWV.png
# Converted 7OZ8auLijd26EwXcIGHo.bytes to byte_images\7OZ8auLijd26EwXcIGHo.png
# Converted 7uqOdRfD2MNowsIh3xUX.bytes to byte_images\7uqOdRfD2MNowsIh3xUX.png
# Converted 7T49Xi2bgMIxcAQKdfky.bytes to byte_images\7T49Xi2bgMIxcAQKdfky.png
# Converted 7s4hmScB9p6HZfNFwVri.bytes to byte_images\7s4hmScB9p6HZfNFwVri.png
# Converted 7UFMw39SLs8Qn4RuIY6W.bytes to byte_images\7UFMw39SLs8Qn4RuIY6W.png
# Converted 7vS8qWAMU6VzbglhF4r3.bytes to byte_images\7vS8qWAMU6VzbglhF4r3.png
# Converted 7sNR0UFCQniz8vbhVpIo.bytes to byte_images\7sNR0UFCQniz8vbhVpIo.png
# Converted 7Uzm5a3KiuTxZPWt8sRb.bytes to byte_images\7Uzm5a3KiuTxZPWt8sRb.png
# Converted 7VlzMYyLUfaWkmPe4huH.bytes to byte_images\7VlzMYyLUfaWkmPe4huH.png
# Converted 7yhwG9NErjks0RDc15B2.bytes to byte_images\7yhwG9NErjks0RDc15B2.png
# Converted 7W4mwlHBPNdcFaViXsrD.bytes to byte_images\7W4mwlHBPNdcFaViXsrD.png
# Converted 7vhxTb5Y8IVO9wHBfyq0.bytes to byte_images\7vhxTb5Y8IVO9wHBfyq0.png
# Converted 7waVJqpLnoxz4fKsZv39.bytes to byte_images\7waVJqpLnoxz4fKsZv39.png
# Converted 7XNob9FGEw6nCSOZT0vJ.bytes to byte_images\7XNob9FGEw6nCSOZT0vJ.png
# Converted 7slN1qRFSycIgd9Qwejx.bytes to byte_images\7slN1qRFSycIgd9Qwejx.png
# Converted 7qY2raQ6izp1KwGcsdyn.bytes to byte_images\7qY2raQ6izp1KwGcsdyn.png
# Converted 82C7lgFmjsNTu9fBdHbi.bytes to byte_images\82C7lgFmjsNTu9fBdHbi.png
# Converted 8a3GEC7cPKtx0lI6qYvL.bytes to byte_images\8a3GEC7cPKtx0lI6qYvL.png
# Converted 82AIq1lR7GwbtSsTWQNP.bytes to byte_images\82AIq1lR7GwbtSsTWQNP.png
# Converted 86ltmd4JPQnVozyK37bB.bytes to byte_images\86ltmd4JPQnVozyK37bB.png
# Converted 85qyLrVc1vhsKCfnNXmx.bytes to byte_images\85qyLrVc1vhsKCfnNXmx.png
# Converted 849LvXpTdqesHuxnwfOG.bytes to byte_images\849LvXpTdqesHuxnwfOG.png
# Converted 8a39lGQmftE0MngbKCqu.bytes to byte_images\8a39lGQmftE0MngbKCqu.png
# Converted 81BI6Ky9bfr4CL3TUkFp.bytes to byte_images\81BI6Ky9bfr4CL3TUkFp.png
# Converted 8c90RlPJHzhmKp1YZN75.bytes to byte_images\8c90RlPJHzhmKp1YZN75.png
# Converted 7zIMcQ35pnFfgE9qr6vs.bytes to byte_images\7zIMcQ35pnFfgE9qr6vs.png
# Converted 8aIkyv7jJRcWpYOD9Ub1.bytes to byte_images\8aIkyv7jJRcWpYOD9Ub1.png
# Converted 8db5LXcqCo9SJBVxQ1g0.bytes to byte_images\8db5LXcqCo9SJBVxQ1g0.png
# Converted 85Mk6byWNR1wCETYisFp.bytes to byte_images\85Mk6byWNR1wCETYisFp.png
# Converted 87Cf2go9YulDiHEyekaS.bytes to byte_images\87Cf2go9YulDiHEyekaS.png
# Converted 8J209kMCyFvWuInbYcio.bytes to byte_images\8J209kMCyFvWuInbYcio.png
# Converted 8F32X71gy4wZrtvmNA6d.bytes to byte_images\8F32X71gy4wZrtvmNA6d.png
# Converted 85qIWFZNGAb6nLug14lH.bytes to byte_images\85qIWFZNGAb6nLug14lH.png
# Converted 8jeHRBlOysCUn9FKaAuf.bytes to byte_images\8jeHRBlOysCUn9FKaAuf.png
# Converted 8odIrLKhPvcDWNCVasUl.bytes to byte_images\8odIrLKhPvcDWNCVasUl.png
# Converted 8cqDWHrnyKRC2Ja9biQ5.bytes to byte_images\8cqDWHrnyKRC2Ja9biQ5.png
# Converted 8cXfpniBZaYVAzg5xt19.bytes to byte_images\8cXfpniBZaYVAzg5xt19.png
# Converted 8qCPkhNr1KJaGtZ35pBc.bytes to byte_images\8qCPkhNr1KJaGtZ35pBc.png
# Converted 85m4HMaLjpTxtlovqZw0.bytes to byte_images\85m4HMaLjpTxtlovqZw0.png
# Converted 8rKwml3nGVhWAiUjDH19.bytes to byte_images\8rKwml3nGVhWAiUjDH19.png
# Converted 8JdntIrPBj61FRx39cfb.bytes to byte_images\8JdntIrPBj61FRx39cfb.png
# Converted 8PuImCboM1zNrUSD7OhV.bytes to byte_images\8PuImCboM1zNrUSD7OhV.png
# Converted 8rSBUFw4tsPubz672vET.bytes to byte_images\8rSBUFw4tsPubz672vET.png
# Converted 8l5jU3sPg4MomRFwL9zT.bytes to byte_images\8l5jU3sPg4MomRFwL9zT.png
# Converted 8pfbAyu34zotUCZwsv2G.bytes to byte_images\8pfbAyu34zotUCZwsv2G.png
# Converted 8rD4bFYzXTVB5IPH1Mdv.bytes to byte_images\8rD4bFYzXTVB5IPH1Mdv.png
# Converted 8inLjyQfkReMHmNUE4qg.bytes to byte_images\8inLjyQfkReMHmNUE4qg.png
# Converted 8MFRorIPmY0iKq5Wz4xB.bytes to byte_images\8MFRorIPmY0iKq5Wz4xB.png
# Converted 8VGXzLxvhH0qIltWc35U.bytes to byte_images\8VGXzLxvhH0qIltWc35U.png
# Converted 8vLGE0QNUBHaK3dt5hyl.bytes to byte_images\8vLGE0QNUBHaK3dt5hyl.png
# Converted 8MSg6ycte4mZsOQL9bVN.bytes to byte_images\8MSg6ycte4mZsOQL9bVN.png
# Converted 8QqTlOsYx5oLychRPgX3.bytes to byte_images\8QqTlOsYx5oLychRPgX3.png
# Converted 8w5bxPTmWXjst7BafQHl.bytes to byte_images\8w5bxPTmWXjst7BafQHl.png
# Converted 8mAqS5PYhyIwls9t1r0Z.bytes to byte_images\8mAqS5PYhyIwls9t1r0Z.png
# Converted 8YF6Rbc7mGV5udHJPMpI.bytes to byte_images\8YF6Rbc7mGV5udHJPMpI.png
# Converted 8YRgqWs2wULtCov0pkT5.bytes to byte_images\8YRgqWs2wULtCov0pkT5.png
# Converted 8VlJEcmXepIy9RS3GMTq.bytes to byte_images\8VlJEcmXepIy9RS3GMTq.png
# Converted 8Vaqh6ofRjLcy2CwpEHZ.bytes to byte_images\8Vaqh6ofRjLcy2CwpEHZ.png
# Converted 91GncYPQHMUTaSuZBqxJ.bytes to byte_images\91GncYPQHMUTaSuZBqxJ.png
# Converted 8w2sWctxOpoIH7VbFREX.bytes to byte_images\8w2sWctxOpoIH7VbFREX.png
# Converted 8xZW7jgeCML04hIw3tOB.bytes to byte_images\8xZW7jgeCML04hIw3tOB.png
# Converted 8VrlyPxXiEU2Bwg5ce3Q.bytes to byte_images\8VrlyPxXiEU2Bwg5ce3Q.png
# Converted 93prvATOY7WiulSKUcRm.bytes to byte_images\93prvATOY7WiulSKUcRm.png
# Converted 93u1tN26E8eySoFxaign.bytes to byte_images\93u1tN26E8eySoFxaign.png
# Converted 972muzardTq3IUKHODvP.bytes to byte_images\972muzardTq3IUKHODvP.png
# Converted 93hSUYmZjMsVpPcHJRCo.bytes to byte_images\93hSUYmZjMsVpPcHJRCo.png
# Converted 93QCNLn5FD2pueg7GdXB.bytes to byte_images\93QCNLn5FD2pueg7GdXB.png
# Converted 9DiHIregYkyCL3lzNvtJ.bytes to byte_images\9DiHIregYkyCL3lzNvtJ.png
# Converted 9eMPNZm0jOhr1SLBDs46.bytes to byte_images\9eMPNZm0jOhr1SLBDs46.png
# Converted 9cuvUrSgBCIq6L3p0He7.bytes to byte_images\9cuvUrSgBCIq6L3p0He7.png
# Converted 93lsPQvIXLHNfCyY2nVr.bytes to byte_images\93lsPQvIXLHNfCyY2nVr.png
# Converted 8XwCLB6D3cMFWT9dtKSA.bytes to byte_images\8XwCLB6D3cMFWT9dtKSA.png
# Converted 9dYh3wO2WUFAH5f8VyKQ.bytes to byte_images\9dYh3wO2WUFAH5f8VyKQ.png
# Converted 8WmlQwgVXPJzeT36c0af.bytes to byte_images\8WmlQwgVXPJzeT36c0af.png
# Converted 9FGfW0bhXZDRKa6dY1Ju.bytes to byte_images\9FGfW0bhXZDRKa6dY1Ju.png
# Converted 974hJRWKfvXaTtNoqMGl.bytes to byte_images\974hJRWKfvXaTtNoqMGl.png
# Converted 92xGBknJqLXYFcgUmjVl.bytes to byte_images\92xGBknJqLXYFcgUmjVl.png
# Converted 9etf3m1LnKEFTNoSj574.bytes to byte_images\9etf3m1LnKEFTNoSj574.png
# Converted 9ftj5a4V8hCr3pTAUiGl.bytes to byte_images\9ftj5a4V8hCr3pTAUiGl.png
# Converted 9lHyVeXERtIaZcL4kWqM.bytes to byte_images\9lHyVeXERtIaZcL4kWqM.png
# Converted 9l5grVFxD4EItfTnqmks.bytes to byte_images\9l5grVFxD4EItfTnqmks.png
# Converted 9hu54PH0G1qoxEmT7AMb.bytes to byte_images\9hu54PH0G1qoxEmT7AMb.png
# Converted 9C7P6vDFXbryOshpKcfn.bytes to byte_images\9C7P6vDFXbryOshpKcfn.png
# Converted 9KBhpLPe6o13q0QHMjk4.bytes to byte_images\9KBhpLPe6o13q0QHMjk4.png
# Converted 9gBVZNKoIPkFM8vOp45G.bytes to byte_images\9gBVZNKoIPkFM8vOp45G.png
# Converted 9itfPnyplHZhTb8IMYq3.bytes to byte_images\9itfPnyplHZhTb8IMYq3.png
# Converted 9kcl1e37zbpLWTPhSoiH.bytes to byte_images\9kcl1e37zbpLWTPhSoiH.pngConverted 9jOk8Tn5JMt4qcXmplfx.bytes to byte_images\9jOk8Tn5JMt4qcXmplfx.png
#
# Converted 9FfKH0kuryGZqiTmglh7.bytes to byte_images\9FfKH0kuryGZqiTmglh7.png
# Converted 9fyAiTPMpZvqX6Khnb7V.bytes to byte_images\9fyAiTPMpZvqX6Khnb7V.png
# Converted 9HAkGKpDrq6hecQZysNd.bytes to byte_images\9HAkGKpDrq6hecQZysNd.png
# Converted 9ml614yxaYqeibfruLWz.bytes to byte_images\9ml614yxaYqeibfruLWz.png
# Converted 9OufdwHvaNyjoQBbePC4.bytes to byte_images\9OufdwHvaNyjoQBbePC4.png
# Converted 9tmX2JACrdeGWHkY3fwi.bytes to byte_images\9tmX2JACrdeGWHkY3fwi.png
# Converted 9M6r8hsleUKTmvfB7Yn2.bytes to byte_images\9M6r8hsleUKTmvfB7Yn2.png
# Converted 9rYnHZKwqkfS43RQ5JhE.bytes to byte_images\9rYnHZKwqkfS43RQ5JhE.png
# Converted 9N7hmb2VQnZoJBvLTWlt.bytes to byte_images\9N7hmb2VQnZoJBvLTWlt.png
# Converted 9MW5Nuf0ogCEcRlYJeKG.bytes to byte_images\9MW5Nuf0ogCEcRlYJeKG.png
# Converted 9PjuhOrlRqxHeQcEBYMX.bytes to byte_images\9PjuhOrlRqxHeQcEBYMX.png
# Converted 9PDzWKXE735IH8V1hoR4.bytes to byte_images\9PDzWKXE735IH8V1hoR4.png
# Converted 9vSJ1dDnwbxl4Fm0By8h.bytes to byte_images\9vSJ1dDnwbxl4Fm0By8h.png
# Converted 9SOPAylKjf2HnxEhRC6I.bytes to byte_images\9SOPAylKjf2HnxEhRC6I.png
# Converted 9MAtXYCG3brN6auwUjQO.bytes to byte_images\9MAtXYCG3brN6auwUjQO.png
# Converted 9Py0kQsvVcHmJe8fZEdT.bytes to byte_images\9Py0kQsvVcHmJe8fZEdT.png
# Converted 9U2dK1jG06Y8kNnPZWM5.bytes to byte_images\9U2dK1jG06Y8kNnPZWM5.png
# Converted 9vS2ZE3gVx1XwkcRioz7.bytes to byte_images\9vS2ZE3gVx1XwkcRioz7.png
# Converted a1u9v0bUgGqk5nBwQ2tm.bytes to byte_images\a1u9v0bUgGqk5nBwQ2tm.png
# Converted 9yEvV8KfDm3hcUZPqBe0.bytes to byte_images\9yEvV8KfDm3hcUZPqBe0.png
# Converted 9XRnlJD64Wzy3gNUhkMC.bytes to byte_images\9XRnlJD64Wzy3gNUhkMC.png
# Converted 9ybCjYPNtAS3pBU7IfdR.bytes to byte_images\9ybCjYPNtAS3pBU7IfdR.png
# Converted a3V71kjmx5AwEivJMuGQ.bytes to byte_images\a3V71kjmx5AwEivJMuGQ.png
# Converted a26fPimxvt4dTLeAVGJH.bytes to byte_images\a26fPimxvt4dTLeAVGJH.png
# Converted 9yEnJoLOWURsBbt2FivP.bytes to byte_images\9yEnJoLOWURsBbt2FivP.png
# Converted a0IC5NMWt9HkBdfOZ8nK.bytes to byte_images\a0IC5NMWt9HkBdfOZ8nK.png
# Converted A4VuQZbt2oGyOkUcvS7W.bytes to byte_images\A4VuQZbt2oGyOkUcvS7W.png
# Converted 9Y2lyb1ocjBFCxJqQEZ3.bytes to byte_images\9Y2lyb1ocjBFCxJqQEZ3.png
# Converted A7g1E4jMhaFSwliBqHnX.bytes to byte_images\A7g1E4jMhaFSwliBqHnX.png
# Converted a4lrvUoF016MZ2m7dczE.bytes to byte_images\a4lrvUoF016MZ2m7dczE.png
# Converted 9sqHEPM5v1ZixBWn8mtl.bytes to byte_images\9sqHEPM5v1ZixBWn8mtl.png
# Converted a63qScpsxBFJtAXjd1nV.bytes to byte_images\a63qScpsxBFJtAXjd1nV.png
# Converted a3BszoA7hXZc0EuHjmwi.bytes to byte_images\a3BszoA7hXZc0EuHjmwi.png
# Converted a82KdTuoj3nB9bU7IfeJ.bytes to byte_images\a82KdTuoj3nB9bU7IfeJ.png
# Converted a9oIzfw03ED4lTBCt52Y.bytes to byte_images\a9oIzfw03ED4lTBCt52Y.png
# Converted a29m3nUocvzC8hBOWkTL.bytes to byte_images\a29m3nUocvzC8hBOWkTL.png
# Converted a7xm4JhCvO9NWVeKMEBn.bytes to byte_images\a7xm4JhCvO9NWVeKMEBn.png
# Converted A8REQ3NzB0dtHFCWDhoc.bytes to byte_images\A8REQ3NzB0dtHFCWDhoc.png
# Converted Ab76U0fJanpo2QwxVN9e.bytes to byte_images\Ab76U0fJanpo2QwxVN9e.png
# Converted a8hZBDrjGiMdtzSklFNV.bytes to byte_images\a8hZBDrjGiMdtzSklFNV.png
# Converted A6RirTm0V4X5OcaS87e2.bytes to byte_images\A6RirTm0V4X5OcaS87e2.png
# Converted a9xbnOcl4UsVTKWjmk10.bytes to byte_images\a9xbnOcl4UsVTKWjmk10.png
# Converted a7Niv6pD5WPycnQK1TZ8.bytes to byte_images\a7Niv6pD5WPycnQK1TZ8.png
# Converted Aa9zCWtbpOo750IlMRdY.bytes to byte_images\Aa9zCWtbpOo750IlMRdY.png
# Converted AafDoztH3lGEhknjFZJM.bytes to byte_images\AafDoztH3lGEhknjFZJM.png
# Converted a9qc1ZCzupOiSsjHdx8e.bytes to byte_images\a9qc1ZCzupOiSsjHdx8e.png
# Converted Aci3M7yVmTuk2SDgNrRw.bytes to byte_images\Aci3M7yVmTuk2SDgNrRw.png
# Converted A8hKH57o1Fj0ZgI4q9QX.bytes to byte_images\A8hKH57o1Fj0ZgI4q9QX.png
# Converted ABedwUfPmn9jv5YNbykK.bytes to byte_images\ABedwUfPmn9jv5YNbykK.png
# Converted acsNRgv9KxMnXAE2YSI6.bytes to byte_images\acsNRgv9KxMnXAE2YSI6.png
# Converted ADIq5LFowdEuPMOGXVcl.bytes to byte_images\ADIq5LFowdEuPMOGXVcl.png
# Converted ABDGLcYxIh1efOnq98vg.bytes to byte_images\ABDGLcYxIh1efOnq98vg.png
# Converted AcIxJCZRTFUpaHove6Qf.bytes to byte_images\AcIxJCZRTFUpaHove6Qf.png
# Converted AbnCYsqpKWGyQE2vh8DV.bytes to byte_images\AbnCYsqpKWGyQE2vh8DV.png
# Converted adrSTjE4bxs63w0oQR8U.bytes to byte_images\adrSTjE4bxs63w0oQR8U.png
# Converted AFY7KdVJNL9ng4pjk1mx.bytes to byte_images\AFY7KdVJNL9ng4pjk1mx.png
# Converted Af0aS7YtTvMFG5jhOquc.bytes to byte_images\Af0aS7YtTvMFG5jhOquc.png
# Converted agqI7DjH6FXER2dNJwVT.bytes to byte_images\agqI7DjH6FXER2dNJwVT.png
# Converted aeS2NqfM8tWdDKUsQgR5.bytes to byte_images\aeS2NqfM8tWdDKUsQgR5.png
# Converted ACTK9tVJunILfsYrwyFh.bytes to byte_images\ACTK9tVJunILfsYrwyFh.png
# Converted AdpPZmQ4xzHO3WwFTqLe.bytes to byte_images\AdpPZmQ4xzHO3WwFTqLe.png
# Converted AgSXb01HILY3mVwfnesd.bytes to byte_images\AgSXb01HILY3mVwfnesd.png
# Converted adxTjKLeEt0HFnUJq1BS.bytes to byte_images\adxTjKLeEt0HFnUJq1BS.png
# Converted ADeT217ZFlhNGQJV4mHk.bytes to byte_images\ADeT217ZFlhNGQJV4mHk.png
# Converted Aep5gJWMNi4P2OLaIV7S.bytes to byte_images\Aep5gJWMNi4P2OLaIV7S.png
# Converted AHzQrG8e6qDat3lpK4M2.bytes to byte_images\AHzQrG8e6qDat3lpK4M2.png
# Converted AhEcNQy9nYHdfzZreoX1.bytes to byte_images\AhEcNQy9nYHdfzZreoX1.png
# Converted ADHdmfR8J6Ebko2P4lqI.bytes to byte_images\ADHdmfR8J6Ebko2P4lqI.png
# Converted aiRmPYXZnQNA509cpthB.bytes to byte_images\aiRmPYXZnQNA509cpthB.png
# Converted aFjtGgxzWAseZRiLJK8I.bytes to byte_images\aFjtGgxzWAseZRiLJK8I.png
# Converted AiBpmbGDE1zPYOT4usqd.bytes to byte_images\AiBpmbGDE1zPYOT4usqd.png
# Converted AithdqZTbgGjRulO3Lz6.bytes to byte_images\AithdqZTbgGjRulO3Lz6.png
# Converted aIGXWDVUyzTcrYAOeBgP.bytes to byte_images\aIGXWDVUyzTcrYAOeBgP.png
# Converted AiaszSGJFhg0wbtyR8Op.bytes to byte_images\AiaszSGJFhg0wbtyR8Op.png
# Converted aiIz8JfYMyPvA4SG6HUO.bytes to byte_images\aiIz8JfYMyPvA4SG6HUO.png
# Converted ahwFAIPcS3yxg1j02KCJ.bytes to byte_images\ahwFAIPcS3yxg1j02KCJ.png
# Converted AJBxQN3qer6FYj1RkbdU.bytes to byte_images\AJBxQN3qer6FYj1RkbdU.png
# Converted aGS0rWZK7vX8TNFUz9ci.bytes to byte_images\aGS0rWZK7vX8TNFUz9ci.png
# Converted AIUyufsTl4xF6BHvVpwh.bytes to byte_images\AIUyufsTl4xF6BHvVpwh.png
# Converted akdGAoZzC9t3jr20Wbyc.bytes to byte_images\akdGAoZzC9t3jr20Wbyc.png
# Converted aIpSDAY9T3rsCwV06Xue.bytes to byte_images\aIpSDAY9T3rsCwV06Xue.png
# Converted Alip9zLkjS5OtryE46Rb.bytes to byte_images\Alip9zLkjS5OtryE46Rb.png
# Converted AlkG3guJPUcqyBadfMFH.bytes to byte_images\AlkG3guJPUcqyBadfMFH.png
# Converted al2koZ501X8hjATSLqgf.bytes to byte_images\al2koZ501X8hjATSLqgf.png
# Converted ajLmuChQW2E3inYtepOH.bytes to byte_images\ajLmuChQW2E3inYtepOH.png
# Converted Ajcs0ECN15RQ237GBbof.bytes to byte_images\Ajcs0ECN15RQ237GBbof.png
# Converted alNJ9v5fdyO2QXruVFsp.bytes to byte_images\alNJ9v5fdyO2QXruVFsp.png
# Converted am8l5JjrXW2hyn3FS4iN.bytes to byte_images\am8l5JjrXW2hyn3FS4iN.png
# Converted ajpIxyzuMmAlJ9cw2HTY.bytes to byte_images\ajpIxyzuMmAlJ9cw2HTY.png
# Converted AM9IXU1wJ5PHfNqoVyxa.bytes to byte_images\AM9IXU1wJ5PHfNqoVyxa.png
# Converted AnLTgxmeksSPClNiQMJv.bytes to byte_images\AnLTgxmeksSPClNiQMJv.png
# Converted aM6vieFrUBwbg8PdWp27.bytes to byte_images\aM6vieFrUBwbg8PdWp27.png
# Converted Am7nEVXHePkCtqsdfzG5.bytes to byte_images\Am7nEVXHePkCtqsdfzG5.png
# Converted AmPVn2SGUxg8IT3BDda9.bytes to byte_images\AmPVn2SGUxg8IT3BDda9.png
# Converted aKQpObrHFW6ymA2uwdXP.bytes to byte_images\aKQpObrHFW6ymA2uwdXP.png
# Converted anNmxI0dCHhXqo6QWYyk.bytes to byte_images\anNmxI0dCHhXqo6QWYyk.png
# Converted aOtVNG6x3empWgK2Zcyd.bytes to byte_images\aOtVNG6x3empWgK2Zcyd.png
# Converted arHTiWpEOMctLjx3Gnv2.bytes to byte_images\arHTiWpEOMctLjx3Gnv2.png
# Converted aQUM2OeWo1PwkhzsXv4x.bytes to byte_images\aQUM2OeWo1PwkhzsXv4x.png
# Converted AOVMlEpXa3N2Tj581QGc.bytes to byte_images\AOVMlEpXa3N2Tj581QGc.png
# Converted ANPyxi13XKGvsF5zlQqW.bytes to byte_images\ANPyxi13XKGvsF5zlQqW.png
# Converted apzPxCsQNhElHbFGBLk3.bytes to byte_images\apzPxCsQNhElHbFGBLk3.png
# Converted APHtWI0Cm8T2yK9ZeBFM.bytes to byte_images\APHtWI0Cm8T2yK9ZeBFM.png
# Converted ASEw3L0HqWMePiy1uKxc.bytes to byte_images\ASEw3L0HqWMePiy1uKxc.png
# Converted Aoa1lgwOyETuRGsIHCe3.bytes to byte_images\Aoa1lgwOyETuRGsIHCe3.png
# Converted AP1FktpMolXv5yEwsKSJ.bytes to byte_images\AP1FktpMolXv5yEwsKSJ.png
# Converted ASDe8bT2BYWLwnOmqFJX.bytes to byte_images\ASDe8bT2BYWLwnOmqFJX.png
# Converted AqwKhntSpCI56vsH7WZe.bytes to byte_images\AqwKhntSpCI56vsH7WZe.png
# Converted aSbnYdE1tq0ivTpCKzFs.bytes to byte_images\aSbnYdE1tq0ivTpCKzFs.png
# Converted ATKzi05WXfeNpJPcvmaZ.bytes to byte_images\ATKzi05WXfeNpJPcvmaZ.png
# Converted AtjeimUnQDzEqb6TN8cC.bytes to byte_images\AtjeimUnQDzEqb6TN8cC.png
# Converted AUdusxNDrKT41q6GimcS.bytes to byte_images\AUdusxNDrKT41q6GimcS.png
# Converted ArX2JQ5sNDhb0lyMoqu6.bytes to byte_images\ArX2JQ5sNDhb0lyMoqu6.png
# Converted atyecAsOdg0rzCXHNvxT.bytes to byte_images\atyecAsOdg0rzCXHNvxT.png
# Converted AtMdKfnuLBgoj17xEsqY.bytes to byte_images\AtMdKfnuLBgoj17xEsqY.png
# Converted Auv3RhZlU6tXcdDQjg2i.bytes to byte_images\Auv3RhZlU6tXcdDQjg2i.png
# Converted aUufGnCVsQDZogv7wHiN.bytes to byte_images\aUufGnCVsQDZogv7wHiN.png
# Converted Aw5bfaXUP67lZN0cjzqO.bytes to byte_images\Aw5bfaXUP67lZN0cjzqO.png
# Converted AmtQlj9uTKxJdONGWca4.bytes to byte_images\AmtQlj9uTKxJdONGWca4.png
# Converted aXbDi405xeqQynl69Yk2.bytes to byte_images\aXbDi405xeqQynl69Yk2.png
# Converted AUHE2QB3peXGCJ5FMcK0.bytes to byte_images\AUHE2QB3peXGCJ5FMcK0.png
# Converted aWXfqViyPYSJHGwOeM07.bytes to byte_images\aWXfqViyPYSJHGwOeM07.png
# Converted ARUDbr2NviE3at0F59sY.bytes to byte_images\ARUDbr2NviE3at0F59sY.png
# Converted AU1Y7aLp3ryXsnWN6oHQ.bytes to byte_images\AU1Y7aLp3ryXsnWN6oHQ.png
# Converted AW0VsbwKSIHgXBZupjGP.bytes to byte_images\AW0VsbwKSIHgXBZupjGP.png
# Converted Auv9HCxOZViJnjMaSIt0.bytes to byte_images\Auv9HCxOZViJnjMaSIt0.png
# Converted Atpz1WjXkcIo7l5TPh9Y.bytes to byte_images\Atpz1WjXkcIo7l5TPh9Y.png
# Converted ASod6eiQyz17bRkglJ5q.bytes to byte_images\ASod6eiQyz17bRkglJ5q.png
# Converted Au5EYTxqCHhdtjBXJfsp.bytes to byte_images\Au5EYTxqCHhdtjBXJfsp.png
# Converted AY0G56vi1jp72ErLmkJb.bytes to byte_images\AY0G56vi1jp72ErLmkJb.png
# Converted axmjW0H3EnB9JRdSibKY.bytes to byte_images\axmjW0H3EnB9JRdSibKY.png
# Converted aylR8xBNVPfJ4eICGLDM.bytes to byte_images\aylR8xBNVPfJ4eICGLDM.png
# Converted axVyZFikJAs2RWgrB37u.bytes to byte_images\axVyZFikJAs2RWgrB37u.png
# Converted aZKEkJF7CQtNSDf64d0P.bytes to byte_images\aZKEkJF7CQtNSDf64d0P.png
# Converted B0QeAmgHpSR3Gi4FDTZl.bytes to byte_images\B0QeAmgHpSR3Gi4FDTZl.png
# Converted AzlMdBSOuma253te0bjX.bytes to byte_images\AzlMdBSOuma253te0bjX.png
# Converted AydrZmxNDPoiRfbvXCW8.bytes to byte_images\AydrZmxNDPoiRfbvXCW8.png
# Converted B063Llt2F9Qpr5ORSbPJ.bytes to byte_images\B063Llt2F9Qpr5ORSbPJ.png
# Converted aXRV9MqCorizGyKJUep0.bytes to byte_images\aXRV9MqCorizGyKJUep0.png
# Converted aYOGVixvL1rIfUSjBtQq.bytes to byte_images\aYOGVixvL1rIfUSjBtQq.png
# Converted AXvM7mlBfJ8eHVDcspNz.bytes to byte_images\AXvM7mlBfJ8eHVDcspNz.png
# Converted b28VuAYhaez0lDPtc6kT.bytes to byte_images\b28VuAYhaez0lDPtc6kT.png
# Converted AVG9IvBRfaEbZn1DhSNp.bytes to byte_images\AVG9IvBRfaEbZn1DhSNp.png
# Converted aZ90qrU6kB3DzFwTVb7o.bytes to byte_images\aZ90qrU6kB3DzFwTVb7o.png
# Converted AyCpqod2kgXKjOnlEbvV.bytes to byte_images\AyCpqod2kgXKjOnlEbvV.png
# Converted b6ZsxrcU9oTlziSwDGVI.bytes to byte_images\b6ZsxrcU9oTlziSwDGVI.png
# Converted Ax7iuDgF38YaQMmX9wVG.bytes to byte_images\Ax7iuDgF38YaQMmX9wVG.png
# Converted b9PJ5cCeBG6NOymu3pfX.bytes to byte_images\b9PJ5cCeBG6NOymu3pfX.png
# Converted B7yT9jiIw8OkC3SMlRAF.bytes to byte_images\B7yT9jiIw8OkC3SMlRAF.png
# Converted B5YUlVtdxFgkTM7mN9Sh.bytes to byte_images\B5YUlVtdxFgkTM7mN9Sh.png
# Converted bakvuMgD2Xfh7JOTKQwm.bytes to byte_images\bakvuMgD2Xfh7JOTKQwm.png
# Converted B8JrNPWkKaxyn5ci1qYb.bytes to byte_images\B8JrNPWkKaxyn5ci1qYb.png
# Converted B3F57b1RXv8cuGZifynU.bytes to byte_images\B3F57b1RXv8cuGZifynU.png
# Converted bAPu2lGC9t5NF0EvZU7H.bytes to byte_images\bAPu2lGC9t5NF0EvZU7H.png
# Converted bDHk4ziTdugcp7jAZlE5.bytes to byte_images\bDHk4ziTdugcp7jAZlE5.png
# Converted banLTf3rYzPjOMK1osqd.bytes to byte_images\banLTf3rYzPjOMK1osqd.png
# Converted BCw58jIVumFW43RExqJk.bytes to byte_images\BCw58jIVumFW43RExqJk.png
# Converted beDosHq791jFfRElVdmi.bytes to byte_images\beDosHq791jFfRElVdmi.png
# Converted BdonVvH3SC2IFgc6NQTh.bytes to byte_images\BdonVvH3SC2IFgc6NQTh.png
# ...
# Converted J1OuMlSZboYIRXC03jQD.bytes to byte_images\J1OuMlSZboYIRXC03jQD.png
# Converted j04fOHCJNI2TkB3lPVyv.bytes to byte_images\j04fOHCJNI2TkB3lPVyv.png
# Converted ixEDUaglAT6ZwM0FGCSu.bytes to byte_images\ixEDUaglAT6ZwM0FGCSu.png
# Converted IZWuOMidGxg1HYNP9fJr.bytes to byte_images\IZWuOMidGxg1HYNP9fJr.png
# Converted j2IBarGQysHh3Cfz6M8i.bytes to byte_images\j2IBarGQysHh3Cfz6M8i.png
# Converted j1lGIRFzMHXnVPZ8DQBg.bytes to byte_images\j1lGIRFzMHXnVPZ8DQBg.png
# Converted j1wqtQ9vlpxD5LMr34aG.bytes to byte_images\j1wqtQ9vlpxD5LMr34aG.png
# Converted Iyjk3mOQfLnRTSqzdCJ1.bytes to byte_images\Iyjk3mOQfLnRTSqzdCJ1.png
# Converted J1LCS4Foa2jbAOYGWQhz.bytes to byte_images\J1LCS4Foa2jbAOYGWQhz.png
# Converted j3tdbX6HDPxA7ZkBUpvG.bytes to byte_images\j3tdbX6HDPxA7ZkBUpvG.png
# Converted j3thgSImoFBZAPsrpaqT.bytes to byte_images\j3thgSImoFBZAPsrpaqT.png
# Converted J9mdlXyFaQjNMtWk21uE.bytes to byte_images\J9mdlXyFaQjNMtWk21uE.png
# Converted J8pdGbHyWis9ToawOIMA.bytes to byte_images\J8pdGbHyWis9ToawOIMA.png
# Converted j3MZQWRstbSx5CG9mpTn.bytes to byte_images\j3MZQWRstbSx5CG9mpTn.png
# Converted J9vHglnKXhiYD4716GWy.bytes to byte_images\J9vHglnKXhiYD4716GWy.png
# Converted J8BlM3NXxq4LzIsrGVPD.bytes to byte_images\J8BlM3NXxq4LzIsrGVPD.png
# Converted jAcaJU6eHy14LPGbnDmT.bytes to byte_images\jAcaJU6eHy14LPGbnDmT.png
# Converted j34R672scXmhMi5zrGkF.bytes to byte_images\j34R672scXmhMi5zrGkF.png
# Converted J9fHxpesDYtIoUc8uZy2.bytes to byte_images\J9fHxpesDYtIoUc8uZy2.png
# Converted j6gIME8eK4T1mn9PFqhb.bytes to byte_images\j6gIME8eK4T1mn9PFqhb.png
# Converted J51yVcCbx9LDM6ZlS4Ud.bytes to byte_images\J51yVcCbx9LDM6ZlS4Ud.png
# Converted JaxoikOjnRvIHFAzBMUD.bytes to byte_images\JaxoikOjnRvIHFAzBMUD.png
# Converted J8EvIQbVSYOXxKC4wgd5.bytes to byte_images\J8EvIQbVSYOXxKC4wgd5.png
# Converted JaQjr806qALIHS2MDZyf.bytes to byte_images\JaQjr806qALIHS2MDZyf.png
# Converted jBRENK34v8VzuSOUQIFJ.bytes to byte_images\jBRENK34v8VzuSOUQIFJ.png
# Converted JBEzM0ZsuWaDt8bLypPv.bytes to byte_images\JBEzM0ZsuWaDt8bLypPv.png
# Converted jBuKaDNdCeyWLkElmpSo.bytes to byte_images\jBuKaDNdCeyWLkElmpSo.png
# Converted JBhPuigxYtENMs4yToa1.bytes to byte_images\JBhPuigxYtENMs4yToa1.png
# Converted jERVLnaTwhHFrZbvNfCy.bytes to byte_images\jERVLnaTwhHFrZbvNfCy.png
# Converted jCrTVsM6f9SOmRP8p14i.bytes to byte_images\jCrTVsM6f9SOmRP8p14i.png
# Converted JbzyqeI9ThRA4LWQN823.bytes to byte_images\JbzyqeI9ThRA4LWQN823.png
# Converted je4HWtx9M5ySpPBO0wgf.bytes to byte_images\je4HWtx9M5ySpPBO0wgf.png
# Converted jDJ2lpYeC6OLvPqWGIsa.bytes to byte_images\jDJ2lpYeC6OLvPqWGIsa.png
# Converted jBXul1FAgEcKxO9ZYCDU.bytes to byte_images\jBXul1FAgEcKxO9ZYCDU.png
# Converted Je7HmzKCW1ocBG3VdOvl.bytes to byte_images\Je7HmzKCW1ocBG3VdOvl.png
# Converted jcH6s8DNVoleU3d9tiZL.bytes to byte_images\jcH6s8DNVoleU3d9tiZL.png
# Converted JbpXH0NYnFwIrzd2fAoW.bytes to byte_images\JbpXH0NYnFwIrzd2fAoW.png
# Converted j6msrVaoBEJ8cWxgZeAH.bytes to byte_images\j6msrVaoBEJ8cWxgZeAH.png
# Converted JEULek2arB86vPXS0lDW.bytes to byte_images\JEULek2arB86vPXS0lDW.png
# Converted jdqclF2YAsm4LJwZUxPN.bytes to byte_images\jdqclF2YAsm4LJwZUxPN.png
# Converted JgtDMQ8WuhPiFxBnalL5.bytes to byte_images\JgtDMQ8WuhPiFxBnalL5.png
# Converted jHEwUGnCVyvB8oguAseJ.bytes to byte_images\jHEwUGnCVyvB8oguAseJ.png
# Converted JflvaIrSi4x0wkjZVN59.bytes to byte_images\JflvaIrSi4x0wkjZVN59.png
# Converted jfn98b4a1ErPWx3thgCN.bytes to byte_images\jfn98b4a1ErPWx3thgCN.png
# Converted jfoOKUzAhdHWvuLeJxCN.bytes to byte_images\jfoOKUzAhdHWvuLeJxCN.png
# Converted jldp5PK6gw1O9t0o7svm.bytes to byte_images\jldp5PK6gw1O9t0o7svm.png
# Converted jIu3J4ovLPUOA6ngmyfw.bytes to byte_images\jIu3J4ovLPUOA6ngmyfw.png
# Converted JhufrNciMQKETOUGZ8Ls.bytes to byte_images\JhufrNciMQKETOUGZ8Ls.png
# Converted jf1ACezG8V546aklihHu.bytes to byte_images\jf1ACezG8V546aklihHu.png
# Converted jlOU12YZu5dLceTICW6K.bytes to byte_images\jlOU12YZu5dLceTICW6K.png
# Converted JIZ5Dg8xYLrfBPUeclHs.bytes to byte_images\JIZ5Dg8xYLrfBPUeclHs.png
# Converted JgoL72E0WlXhmFHD5cxp.bytes to byte_images\JgoL72E0WlXhmFHD5cxp.png
# Converted JO58MAdl0WiuFk9zhspH.bytes to byte_images\JO58MAdl0WiuFk9zhspH.png
# Converted jF8Qxdo3MyVEc9l6O2B1.bytes to byte_images\jF8Qxdo3MyVEc9l6O2B1.png
# Converted JNGf3qzH2oLvBXDSM6Fp.bytes to byte_images\JNGf3qzH2oLvBXDSM6Fp.png
# Converted JGpFMd5bZlkQ18fxNcwn.bytes to byte_images\JGpFMd5bZlkQ18fxNcwn.png
# Converted JkoiGmLfBj4FtErK1VOH.bytes to byte_images\JkoiGmLfBj4FtErK1VOH.png
# Converted jmPeQlFEcqyRuVwrJTvp.bytes to byte_images\jmPeQlFEcqyRuVwrJTvp.png
# Converted jmvJqEQ1VNh3ukH6cIRK.bytes to byte_images\jmvJqEQ1VNh3ukH6cIRK.png
# Converted JQ7wRLlnb6WqEkd28mgF.bytes to byte_images\JQ7wRLlnb6WqEkd28mgF.png
# Converted jM2ezG5TVpPDmlEBZN7b.bytes to byte_images\jM2ezG5TVpPDmlEBZN7b.png
# Converted jLtKBPl5Xk6peO9DWucy.bytes to byte_images\jLtKBPl5Xk6peO9DWucy.png
# Converted JhSGQb9mvEYIXVd0z8U2.bytes to byte_images\JhSGQb9mvEYIXVd0z8U2.png
# Converted jPwdh0NtUaR9T4MIWcuE.bytes to byte_images\jPwdh0NtUaR9T4MIWcuE.png
# Converted jOTtmr8uJvclSIBf1xHo.bytes to byte_images\jOTtmr8uJvclSIBf1xHo.png
# Converted jQqeMNUahpkbZI18c49o.bytes to byte_images\jQqeMNUahpkbZI18c49o.png
# Converted JrFfspKABcSqx2zmTnCg.bytes to byte_images\JrFfspKABcSqx2zmTnCg.png
# Converted JqMnmvEYlKVfw90W6btB.bytes to byte_images\JqMnmvEYlKVfw90W6btB.png
# Converted jOPwcHh7kyFaB4Yv8SMU.bytes to byte_images\jOPwcHh7kyFaB4Yv8SMU.png
# Converted JQHf0c52agNmervIpCkT.bytes to byte_images\JQHf0c52agNmervIpCkT.png
# Converted js068WDIg1hXYHKPriod.bytes to byte_images\js068WDIg1hXYHKPriod.png
# Converted jrg4n6P8cIGoSBXyWAtp.bytes to byte_images\jrg4n6P8cIGoSBXyWAtp.png
# Converted Jt9n0B4wTIpYCAko1ZQE.bytes to byte_images\Jt9n0B4wTIpYCAko1ZQE.png
# Converted jSMI8XxFJhHAWa15GozR.bytes to byte_images\jSMI8XxFJhHAWa15GozR.png
# Converted JSYxG6FyPnqQzEp73B9e.bytes to byte_images\JSYxG6FyPnqQzEp73B9e.png
# Converted Jt3kj7AHvPdRfL6yCh2n.bytes to byte_images\Jt3kj7AHvPdRfL6yCh2n.png
# Converted JSYQ5GPfsFt8H0VRDdZv.bytes to byte_images\JSYQ5GPfsFt8H0VRDdZv.png
# Converted jpzob9ECS6aLQDiYWTkV.bytes to byte_images\jpzob9ECS6aLQDiYWTkV.png
# Converted JrsqMWaubVkZ3vj9himO.bytes to byte_images\JrsqMWaubVkZ3vj9himO.png
# Converted JPz2sCNRcjVUDrwLh8S3.bytes to byte_images\JPz2sCNRcjVUDrwLh8S3.png
# Converted jpdhY15v8mkeftGiF4VA.bytes to byte_images\jpdhY15v8mkeftGiF4VA.png
# Converted ju23GQl4DYFVeNwc85ka.bytes to byte_images\ju23GQl4DYFVeNwc85ka.png
# Converted jSbcLy3rlkYhEd927p0P.bytes to byte_images\jSbcLy3rlkYhEd927p0P.png
# Converted JufSg9mpGi1dVZ0C7zWA.bytes to byte_images\JufSg9mpGi1dVZ0C7zWA.png
# Converted JUKui8IlmdXj7DVLn56e.bytes to byte_images\JUKui8IlmdXj7DVLn56e.png
# Converted JTAoQ9miHalVeE63PdBU.bytes to byte_images\JTAoQ9miHalVeE63PdBU.png
# Converted JUCpOmLGibKr7gdPHfhj.bytes to byte_images\JUCpOmLGibKr7gdPHfhj.png
# Converted jtbI230ofwYMxRuFdpzX.bytes to byte_images\jtbI230ofwYMxRuFdpzX.png
# Converted Ju4nWgOCHXBlyZmTo51e.bytes to byte_images\Ju4nWgOCHXBlyZmTo51e.png
# Converted jULaFyfMxw9nPWX6uK12.bytes to byte_images\jULaFyfMxw9nPWX6uK12.png
# Converted JudsxDwAcT2XRjZkC7Yv.bytes to byte_images\JudsxDwAcT2XRjZkC7Yv.png
# Converted JvHA2RcsbZqDQ5ETtog3.bytes to byte_images\JvHA2RcsbZqDQ5ETtog3.png
# Converted jUK5O9P6bJSAiMD0ofQy.bytes to byte_images\jUK5O9P6bJSAiMD0ofQy.png
# Converted juGVt8nSNeo7OJr2p0md.bytes to byte_images\juGVt8nSNeo7OJr2p0md.png
# Converted JVSdyxfAB2Y3KT4ZihCk.bytes to byte_images\JVSdyxfAB2Y3KT4ZihCk.png
# Converted jwzRSkGXbLEaZMsguQc3.bytes to byte_images\jwzRSkGXbLEaZMsguQc3.png
# Converted JunATHDXOfYZFlRpahV1.bytes to byte_images\JunATHDXOfYZFlRpahV1.png
# Converted JW5KOAExTVe2qH3kM4SD.bytes to byte_images\JW5KOAExTVe2qH3kM4SD.png
# Converted JXbBkuvnYF1tCANOlZy6.bytes to byte_images\JXbBkuvnYF1tCANOlZy6.png
# Converted jVEk2G0fyQUiNWbxAzch.bytes to byte_images\jVEk2G0fyQUiNWbxAzch.png
# Converted jy6vK4hB8Z2eYMFXdkbP.bytes to byte_images\jy6vK4hB8Z2eYMFXdkbP.png
# Converted JwXPAuRDQva5FYe8t30z.bytes to byte_images\JwXPAuRDQva5FYe8t30z.png
# Converted JyABO1D3n0kxMLIWq25g.bytes to byte_images\JyABO1D3n0kxMLIWq25g.png
# Converted jwJRB9KOeGsc4ME7WXuy.bytes to byte_images\jwJRB9KOeGsc4ME7WXuy.png
# Converted JxGT97ynUebwfFQZvdu6.bytes to byte_images\JxGT97ynUebwfFQZvdu6.png
# Converted JYEvhBDFS2aNocqUwkMb.bytes to byte_images\JYEvhBDFS2aNocqUwkMb.png
# Converted JUO3pfywZnC4e9xHLBMA.bytes to byte_images\JUO3pfywZnC4e9xHLBMA.png
# Converted JycBQ9bRKZChEMI4DWPe.bytes to byte_images\JycBQ9bRKZChEMI4DWPe.png
# Converted jzf91HDNIbFMPaKEmZvL.bytes to byte_images\jzf91HDNIbFMPaKEmZvL.png
# Converted JVPnwpfeExcNDt2ZTAQm.bytes to byte_images\JVPnwpfeExcNDt2ZTAQm.png
# Converted jxgaANiB20rR4UuSveCs.bytes to byte_images\jxgaANiB20rR4UuSveCs.png
# Converted JV6Qew1hoIUYF7uiCz4L.bytes to byte_images\JV6Qew1hoIUYF7uiCz4L.png
# Converted jYWpNLrtc2ns0kMizPgX.bytes to byte_images\jYWpNLrtc2ns0kMizPgX.png
# Converted JzF18ftmDC3VOLnIAhWP.bytes to byte_images\JzF18ftmDC3VOLnIAhWP.png
# Converted JySEQsbmRtqxuN2D5IYO.bytes to byte_images\JySEQsbmRtqxuN2D5IYO.png
# Converted JyExpTqVMmeA2wH0FbkY.bytes to byte_images\JyExpTqVMmeA2wH0FbkY.png
# Converted JZxp9mEVqv81h4s2YkCD.bytes to byte_images\JZxp9mEVqv81h4s2YkCD.png
# Converted k2uRGpoUItiWrTga9ysQ.bytes to byte_images\k2uRGpoUItiWrTga9ysQ.png
# Converted JzTXaNDCqKGuiEvrHOYS.bytes to byte_images\JzTXaNDCqKGuiEvrHOYS.png
# Converted k2dfrliR13sGtuCTc4B7.bytes to byte_images\k2dfrliR13sGtuCTc4B7.png
# Converted K17ifkYqXgNOHav8uzCL.bytes to byte_images\K17ifkYqXgNOHav8uzCL.png
# Converted JzqSF8afm6XETrWbLpHl.bytes to byte_images\JzqSF8afm6XETrWbLpHl.png
# Converted k1fUSL4R0yqnAoEdQvlD.bytes to byte_images\k1fUSL4R0yqnAoEdQvlD.png
# Converted jynSzuQrYfI7eGHWKmPZ.bytes to byte_images\jynSzuQrYfI7eGHWKmPZ.png
# Converted jzWGYQn7q2fuCKNcUpAx.bytes to byte_images\jzWGYQn7q2fuCKNcUpAx.png
# Converted JUr6yTFW3ExqApBt5S2z.bytes to byte_images\JUr6yTFW3ExqApBt5S2z.png
# Converted K5g1aRrQn3tXvPbLGpMS.bytes to byte_images\K5g1aRrQn3tXvPbLGpMS.png
# Converted k3Gv04b1HUEMmrPCJAct.bytes to byte_images\k3Gv04b1HUEMmrPCJAct.png
# Converted JWZspDnaHodqzRly0fMg.bytes to byte_images\JWZspDnaHodqzRly0fMg.png
# Converted k8eJUjLvbnw0NCI4Ttu2.bytes to byte_images\k8eJUjLvbnw0NCI4Ttu2.png
# Converted K9kNdLS83clsP0wDFObZ.bytes to byte_images\K9kNdLS83clsP0wDFObZ.png
# Converted k7Xf4A2MhsF9jgiD1UGE.bytes to byte_images\k7Xf4A2MhsF9jgiD1UGE.png
# Converted k6Mnj2POrsKEqVxeNJAu.bytes to byte_images\k6Mnj2POrsKEqVxeNJAu.png
# Converted K47QO8LZycVNdTRu2F0P.bytes to byte_images\K47QO8LZycVNdTRu2F0P.png
# Converted k8qrhNTAG54fSl6jDtVa.bytes to byte_images\k8qrhNTAG54fSl6jDtVa.png
# Converted K4jGPJV6DUu7Xq1eFdrB.bytes to byte_images\K4jGPJV6DUu7Xq1eFdrB.png
# Converted K4hfUQFEiTBqIPauRYdp.bytes to byte_images\K4hfUQFEiTBqIPauRYdp.png
# Converted K3BiLDx5eFqoG2tETujV.bytes to byte_images\K3BiLDx5eFqoG2tETujV.png
# Converted k2mxrqNg1JzRiVsIbytQ.bytes to byte_images\k2mxrqNg1JzRiVsIbytQ.pngConverted K70AVwRbXjTFZv9g463D.bytes to byte_images\K70AVwRbXjTFZv9g463D.png
#
# Converted KAVHCXZWDib1zxPOqINJ.bytes to byte_images\KAVHCXZWDib1zxPOqINJ.png
# Converted KAGfZUyown7ieqDOgBYr.bytes to byte_images\KAGfZUyown7ieqDOgBYr.png
# Converted kBdDKj9W1rQPpoHmetaG.bytes to byte_images\kBdDKj9W1rQPpoHmetaG.png
# Converted kcAwuM18pnvfbgIos570.bytes to byte_images\kcAwuM18pnvfbgIos570.png
# Converted kei4pRX9ENQaKFsLcOU1.bytes to byte_images\kei4pRX9ENQaKFsLcOU1.png
# Converted kczYF5vSxW3ZrilfJesd.bytes to byte_images\kczYF5vSxW3ZrilfJesd.png
# Converted kc01Wwz52sCaEVlFXgpG.bytes to byte_images\kc01Wwz52sCaEVlFXgpG.png
# Converted kcpjm3bSZFrIltvNVTMW.bytes to byte_images\kcpjm3bSZFrIltvNVTMW.png
# Converted kAQCMqUNsZDoribmvw84.bytes to byte_images\kAQCMqUNsZDoribmvw84.png
# Converted kDyOh6d8WQNTEoxJYUg1.bytes to byte_images\kDyOh6d8WQNTEoxJYUg1.png
# Converted KcfgCTNF3aMdqJ0jyWSG.bytes to byte_images\KcfgCTNF3aMdqJ0jyWSG.png
# Converted kdmNfXGWslxUa3yATSFw.bytes to byte_images\kdmNfXGWslxUa3yATSFw.png
# Converted kdzj2p0qHin4fMBCaPF5.bytes to byte_images\kdzj2p0qHin4fMBCaPF5.png
# Converted KBvLr7Tk8OuoySgdA6eY.bytes to byte_images\KBvLr7Tk8OuoySgdA6eY.png
# Converted k9Vp4RQczHiGXIJ10qMf.bytes to byte_images\k9Vp4RQczHiGXIJ10qMf.png
# Converted kG29BLiFYPgWtpb350sO.bytes to byte_images\kG29BLiFYPgWtpb350sO.png
# Converted KHmRYShqZacoQEOJx862.bytes to byte_images\KHmRYShqZacoQEOJx862.png
# Converted Ki1pYrmszFSjuWUvHIqk.bytes to byte_images\Ki1pYrmszFSjuWUvHIqk.png
# Converted ki3Fo5dh6yWAqOCBrEXP.bytes to byte_images\ki3Fo5dh6yWAqOCBrEXP.png
# Converted kflLjmJz8FGsprySOqoX.bytes to byte_images\kflLjmJz8FGsprySOqoX.png
# Converted kGf3NUtFcq2wCSD0Yeuz.bytes to byte_images\kGf3NUtFcq2wCSD0Yeuz.png
# Converted kgfPdjYxa5GtleWVrvEM.bytes to byte_images\kgfPdjYxa5GtleWVrvEM.png
# Converted kLMHFv8hXS0atbDf7nGY.bytes to byte_images\kLMHFv8hXS0atbDf7nGY.png
# Converted kjn4yXdo0iLCmZ9GugOV.bytes to byte_images\kjn4yXdo0iLCmZ9GugOV.png
# Converted KLaDWc2xvMJOdo87b9Zf.bytes to byte_images\KLaDWc2xvMJOdo87b9Zf.png
# Converted kl6Lw0U7WYT2biJXhP3y.bytes to byte_images\kl6Lw0U7WYT2biJXhP3y.png
# Converted kIpOXia5GrTjeNzV9K13.bytes to byte_images\kIpOXia5GrTjeNzV9K13.png
# Converted KGTOj6HAvNqWUcP27bCf.bytes to byte_images\KGTOj6HAvNqWUcP27bCf.png
# Converted KHtk3pyb0qUlQr9hJda6.bytes to byte_images\KHtk3pyb0qUlQr9hJda6.png
# Converted kGITL4OJxYMWEQ1bKBiP.bytes to byte_images\kGITL4OJxYMWEQ1bKBiP.png
# Converted KIMkclhHJbdsR5218rzq.bytes to byte_images\KIMkclhHJbdsR5218rzq.png
# Converted kg24YRJTB8DNdKMXpwOH.bytes to byte_images\kg24YRJTB8DNdKMXpwOH.png
# Converted kI2PQoudeFEDYOBTliUf.bytes to byte_images\kI2PQoudeFEDYOBTliUf.png
# Converted kMAlu9InmCyvPpEDL46i.bytes to byte_images\kMAlu9InmCyvPpEDL46i.png
# Converted kMJ8PQiEqdOx1wmF4cKI.bytes to byte_images\kMJ8PQiEqdOx1wmF4cKI.png
# Converted ksTyZ4jN21lBiC9UYOGe.bytes to byte_images\ksTyZ4jN21lBiC9UYOGe.png
# Converted l06yuHvrqdzTo8CQeAO5.bytes to byte_images\l06yuHvrqdzTo8CQeAO5.png
# Converted KXy5fwEeZon9r6bHAvRg.bytes to byte_images\KXy5fwEeZon9r6bHAvRg.png
# Converted kMDrx5LS2P864CIwNiVs.bytes to byte_images\kMDrx5LS2P864CIwNiVs.png
# Converted kMdOa9cZ3jw8GUFu52Tq.bytes to byte_images\kMdOa9cZ3jw8GUFu52Tq.png
# Converted kqiOdVbRQlB2s907GLMv.bytes to byte_images\kqiOdVbRQlB2s907GLMv.png
# Converted KMAcej7qgX5u9RbTUZ0x.bytes to byte_images\KMAcej7qgX5u9RbTUZ0x.png
# Converted KQwj9O6dlPxNyf8zW0gp.bytes to byte_images\KQwj9O6dlPxNyf8zW0gp.png
# Converted KNP2ROq6J8YEcmyrtSjV.bytes to byte_images\KNP2ROq6J8YEcmyrtSjV.png
# Converted KWg8T3NOYaQBF0tMqLm5.bytes to byte_images\KWg8T3NOYaQBF0tMqLm5.png
# Converted KM7grcA6yBk1J0CmaWiP.bytes to byte_images\KM7grcA6yBk1J0CmaWiP.png
# Converted KNlAmtEIizBU7X5H1PwQ.bytes to byte_images\KNlAmtEIizBU7X5H1PwQ.png
# Converted l387nbiI4TU9LNMQt1Fe.bytes to byte_images\l387nbiI4TU9LNMQt1Fe.png
# Converted l5zY6vNZbOKF07uSn2Am.bytes to byte_images\l5zY6vNZbOKF07uSn2Am.png
# Converted ldNfaCpceLnGUE0rPzqF.bytes to byte_images\ldNfaCpceLnGUE0rPzqF.png
# Converted lBuYeZUbtHQVsh7Tn2NJ.bytes to byte_images\lBuYeZUbtHQVsh7Tn2NJ.png
# Converted L1o7HeFKzONsb3JvRy82.bytes to byte_images\L1o7HeFKzONsb3JvRy82.png
# Converted lcqv9STBAX20houtQnR3.bytes to byte_images\lcqv9STBAX20houtQnR3.png
# Converted L1OGj5BEh2drf0Wtiu9N.bytes to byte_images\L1OGj5BEh2drf0Wtiu9N.png
# Converted L2QwdUyG0HISDVk8rcsE.bytes to byte_images\L2QwdUyG0HISDVk8rcsE.png
# Converted KqEgONxfHdP5lLaBIGQk.bytes to byte_images\KqEgONxfHdP5lLaBIGQk.png
# Converted LEnDGzVIjHaqmrPMJyR0.bytes to byte_images\LEnDGzVIjHaqmrPMJyR0.png
# Converted lS0IVqXeJrN6Dzi9Pap1.bytes to byte_images\lS0IVqXeJrN6Dzi9Pap1.png
# Converted l1OdNtIKM8Gi6jowZHg3.bytes to byte_images\l1OdNtIKM8Gi6jowZHg3.png
# Converted ljFT1KeZmEiHxhuRbrcd.bytes to byte_images\ljFT1KeZmEiHxhuRbrcd.png
# Converted LH5pzdDSPOtgIaBC1jWo.bytes to byte_images\LH5pzdDSPOtgIaBC1jWo.png
# Converted loIP1tiwELF9YNZQjSUO.bytes to byte_images\loIP1tiwELF9YNZQjSUO.png
# Converted l0PMq9Be5ft1ciaF4IwC.bytes to byte_images\l0PMq9Be5ft1ciaF4IwC.png
# Converted LfVY3tPrRZHGQ2SdJm5x.bytes to byte_images\LfVY3tPrRZHGQ2SdJm5x.png
# Converted L0xnGubfYwOPpQAgVNvo.bytes to byte_images\L0xnGubfYwOPpQAgVNvo.png
# Converted ljuryB4bfagHqV5FM9Ae.bytes to byte_images\ljuryB4bfagHqV5FM9Ae.png
# Conversion of byte files to PNG images completed.
# Time taken: 23 m 5 s

# %% [markdown]
# Need to resize images to a certain size? (maybe 256x256??) or pad?? or cut???

# %% [markdown]
# ## Train Test Split

# %%
start = time.time()

# Define the paths
byte_images_folder = './byte_images'
train_folder = './train_byte_image'
test_folder = './test_byte_image'
train_labels_path = './train_labels.csv'
test_labels_path = './test_labels.csv'

# Create train and test directories if they don't exist
os.makedirs(train_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)

# Load the CSV files into DataFrames
train_labels_df = pd.read_csv(train_labels_path)
test_labels_df = pd.read_csv(test_labels_path)

# Get the list of IDs from train and test CSV files
train_ids = train_labels_df['Id'].tolist()
test_ids = test_labels_df['Id'].tolist()

# Iterate through the images in the byte_images folder
for filename in os.listdir(byte_images_folder):
    # Extract the file ID (without the .png extension)
    file_id = filename.replace('.png', '')

    # Check if the file ID is in train or test labels
    source_path = os.path.join(byte_images_folder, filename)
    if file_id in train_ids:
        # Move the file to the train_byte_image folder
        shutil.move(source_path, os.path.join(train_folder, filename))
    elif file_id in test_ids:
        # Move the file to the test_byte_image folder
        shutil.move(source_path, os.path.join(test_folder, filename))

print("Files have been moved to the respective directories.")

end = time.time()

print("Time taken: {} m {} s".format(int((end-start)//60), int((end-start)%60)))
# Out:
# Files have been moved to the respective directories.
# Time taken: 0 m 2 s
