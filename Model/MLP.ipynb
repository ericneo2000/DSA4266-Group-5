# %% [markdown]
# ## Import Libraries

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Read datasets

# %%
asm_1_gram = pd.read_csv('asm_features_1_gram_dropped.csv')
asm_2_gram = pd.read_csv('asm_features_2_grams_dropped.csv')
asm_prefix_counts = pd.read_csv('asm_prefix_counts.csv')
bytes_1_gram = pd.read_csv('bytes_features_1_grams.csv')
bytes_2_gram = pd.read_csv('top_170_imp_byte_bigram_df.csv')
file_sizes = pd.read_csv('file_sizes.csv')
dll = pd.read_csv('dll_occurences.csv')
punctuation = pd.read_csv('punctuation_occurences.csv')

# %%
file_sizes.columns
# Out:
# Index(['File ID', 'Bytes File Size', 'ASM File Size', 'Ratio'], dtype='object')

# %%
train_labels = pd.read_csv('train_labels.csv')
test_labels = pd.read_csv('test_labels.csv')
train_labels = train_labels.drop('Unnamed: 0', axis=1)
test_labels = test_labels.drop('Unnamed: 0', axis=1)
train_labels = train_labels.rename(columns={'Id':'ID'})
test_labels = test_labels.rename(columns={'Id':'ID'})

# %% [markdown]
# ## Join datasets into 1 df

# %%
def recursive_join(files):
  df = files[0]
  for i in range(1, len(files)):
    # print(i)
    df = df.merge(files[i], on= 'ID', how= 'inner')
    # print(df.head())
  return df

# %%
asm_prefix_counts = asm_prefix_counts.rename(columns={'File ID':'ID'})
file_sizes = file_sizes.rename(columns={'File ID':'ID'})
train_labels = train_labels.rename(columns={'Id':'ID'})
test_labels = test_labels.rename(columns={'Id':'ID'})

# %%
all_files = [asm_1_gram, asm_2_gram, asm_prefix_counts, bytes_1_gram, bytes_2_gram, file_sizes, dll, punctuation]
asm_files = [asm_1_gram, asm_2_gram, asm_prefix_counts, file_sizes[['ID', 'ASM File Size']], dll, punctuation]
bytes_files = [bytes_1_gram, bytes_2_gram, file_sizes[['ID', 'Bytes File Size']]]

# %% [markdown]
# ## Data Preprocessing

# %%
all_data = recursive_join(all_files)
asm_data = recursive_join(asm_files)
bytes_data = recursive_join(bytes_files)

# %%
# Select columns with string (object) data type
string_columns_all = all_data.select_dtypes(include='object').columns.tolist()
string_columns_asm = asm_data.select_dtypes(include='object').columns.tolist()
string_columns_bytes = bytes_data.select_dtypes(include='object').columns.tolist()
#
# print("String columns:", string_columns)

# %%
id_col_all = all_data['ID']
all_data = all_data.drop(string_columns_all, axis=1)

id_col_asm = asm_data['ID']
asm_data = asm_data.drop(string_columns_asm, axis=1)

id_col_bytes = bytes_data['ID']
bytes_data = bytes_data.drop(string_columns_bytes, axis=1)

# %%
asm_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Columns: 189 entries, add to _
# dtypes: int64(189)
# memory usage: 2.3 MB

# %%
data_normalized_all = pd.DataFrame(tf.math.l2_normalize(all_data, axis=0), columns = all_data.columns)
data_normalized_asm = pd.DataFrame(tf.math.l2_normalize(asm_data.astype('float64'), axis=0), columns = asm_data.columns)
data_normalized_bytes = pd.DataFrame(tf.math.l2_normalize(bytes_data, axis=0), columns = bytes_data.columns)

# Add ID column back
data_normalized_all = pd.concat([id_col_all, data_normalized_all], axis=1)
data_normalized_asm = pd.concat([id_col_asm, data_normalized_asm], axis=1)
data_normalized_bytes = pd.concat([id_col_bytes, data_normalized_bytes], axis=1)

# %% [markdown]
# ## Train Test Split

# %%
train_data_all = pd.merge(train_labels, data_normalized_all, on='ID', how='inner').sort_values(by='ID', key=lambda x: x.str.lower())
test_data_all = pd.merge(test_labels, data_normalized_all, on='ID', how='inner').sort_values(by='ID', key=lambda x: x.str.lower())
train_data_asm = pd.merge(train_labels, data_normalized_asm, on='ID', how='inner').sort_values(by='ID', key=lambda x: x.str.lower())
test_data_asm = pd.merge(test_labels, data_normalized_asm, on='ID', how='inner').sort_values(by='ID', key=lambda x: x.str.lower())
train_data_bytes = pd.merge(train_labels, data_normalized_bytes, on='ID', how='inner').sort_values(by='ID', key=lambda x: x.str.lower())
test_data_bytes = pd.merge(test_labels, data_normalized_bytes, on='ID', how='inner').sort_values(by='ID', key=lambda x: x.str.lower())

# %%
y_train_all = train_data_all['Class']
y_test_all = test_data_all['Class']
y_train_asm = train_data_asm['Class']
y_test_asm = test_data_asm['Class']
y_train_bytes = train_data_bytes['Class']
y_test_bytes = test_data_bytes['Class']

# %%
X_train_all = train_data_all.drop(['ID', 'Class'], axis=1).fillna(0)
X_test_all = test_data_all.drop(['ID', 'Class'], axis=1).fillna(0)
X_train_asm = train_data_asm.drop(['ID', 'Class'], axis=1).fillna(0)
X_test_asm = test_data_asm.drop(['ID', 'Class'], axis=1).fillna(0)
X_train_bytes = train_data_bytes.drop(['ID', 'Class'], axis=1).fillna(0)
X_test_bytes = test_data_bytes.drop(['ID', 'Class'], axis=1).fillna(0)

# %%
import numpy as np
def one_hot_encode(labels):
    labels = np.array(labels)
    labels[labels < 5] = labels[labels < 5] - 1
    labels[labels > 5] = labels[labels > 5] - 2
    encoded_labels = np.identity(8)[labels]
    return encoded_labels

# %%
y_train_one_hot_all = one_hot_encode(y_train_all)
y_test_one_hot_all = one_hot_encode(y_test_all)
y_train_one_hot_asm = one_hot_encode(y_train_asm)
y_test_one_hot_asm = one_hot_encode(y_test_asm)
y_train_one_hot_bytes = one_hot_encode(y_train_bytes)
y_test_one_hot_bytes = one_hot_encode(y_test_bytes)

# %% [markdown]
# ## MLP

# %%
len(X_train_bytes.columns)
# Out:
# 428

# %%
from tensorflow.keras.regularizers import L2
from tensorflow.keras.activations import leaky_relu
from tensorflow.keras.initializers import HeNormal

model_all = Sequential([
    Dense(64, input_shape=(618,), activation='leaky_relu', kernel_regularizer=L2(0.001), kernel_initializer=HeNormal()),
    Dense(128, activation='leaky_relu', kernel_regularizer=L2(0.001)),
    Dense(64, activation='leaky_relu', kernel_regularizer=L2(0.001)),
    Dense(32, activation='leaky_relu', kernel_regularizer=L2(0.001)),
    Dense(8, activation='softmax')
]
)

model_asm = Sequential([
    Dense(64, input_shape=(189,), activation='leaky_relu', kernel_regularizer=L2(0.001), kernel_initializer=HeNormal()),
    Dense(128, activation='leaky_relu', kernel_regularizer=L2(0.001)),
    Dense(64, activation='leaky_relu', kernel_regularizer=L2(0.001)),
    Dense(32, activation='leaky_relu', kernel_regularizer=L2(0.001)),
    Dense(8, activation='softmax')
]
)

model_bytes = Sequential([
    Dense(64, input_shape=(428,), activation='leaky_relu', kernel_regularizer=L2(0.001), kernel_initializer=HeNormal()),
    Dense(128, activation='leaky_relu', kernel_regularizer=L2(0.001)),
    Dense(64, activation='leaky_relu', kernel_regularizer=L2(0.001)),
    Dense(32, activation='leaky_relu', kernel_regularizer=L2(0.001)),
    Dense(8, activation='softmax')
]
)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from tensorflow.keras.optimizers import Adam

# Compile the model
model_all.compile(optimizer=Adam(learning_rate=0.001, clipnorm = 1.0), loss=tf.keras.losses.categorical_crossentropy, metrics=['accuracy'])
model_asm.compile(optimizer=Adam(learning_rate=0.001, clipnorm = 1.0), loss=tf.keras.losses.categorical_crossentropy, metrics=['accuracy'])
model_bytes.compile(optimizer=Adam(learning_rate=0.001, clipnorm = 1.0), loss=tf.keras.losses.categorical_crossentropy, metrics=['accuracy'])

# Display the model summary
model_all.summary()
model_asm.summary()
model_bytes.summary()
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_45 (Dense)                     │ (None, 64)                  │          39,616 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_46 (Dense)                     │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_47 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_48 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_49 (Dense)                     │ (None, 8)                   │             264 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 58,536 (228.66 KB)
#  Trainable params: 58,536 (228.66 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_50 (Dense)                     │ (None, 64)                  │          12,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_51 (Dense)                     │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_52 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_53 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_54 (Dense)                     │ (None, 8)                   │             264 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 31,080 (121.41 KB)
#  Trainable params: 31,080 (121.41 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_55 (Dense)                     │ (None, 64)                  │          27,456 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_56 (Dense)                     │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_57 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_58 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_59 (Dense)                     │ (None, 8)                   │             264 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 46,376 (181.16 KB)
#  Trainable params: 46,376 (181.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_all = model_all.fit(X_train_all, y_train_one_hot_all, epochs=50, validation_data = (X_test_all, y_test_one_hot_all))
history_asm = model_asm.fit(X_train_asm, y_train_one_hot_asm, epochs=50, validation_data = (X_test_asm, y_test_one_hot_asm))
history_bytes = model_bytes.fit(X_train_bytes, y_train_one_hot_bytes, epochs=50, validation_data = (X_test_bytes, y_test_one_hot_bytes))
# Out:
# Epoch 1/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.1744 - loss: 2.3594 - val_accuracy: 0.3438 - val_loss: 2.1661
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3482 - loss: 2.0208 - val_accuracy: 0.4719 - val_loss: 1.6173
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5369 - loss: 1.5426 - val_accuracy: 0.8438 - val_loss: 1.1367
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8426 - loss: 1.0038 - val_accuracy: 0.8625 - val_loss: 0.8573
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8865 - loss: 0.7504 - val_accuracy: 0.8531 - val_loss: 0.7661
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8864 - loss: 0.6791 - val_accuracy: 0.9031 - val_loss: 0.6177
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9126 - loss: 0.5571 - val_accuracy: 0.9406 - val_loss: 0.5901
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9429 - loss: 0.4934 - val_accuracy: 0.9187 - val_loss: 0.5955
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9388 - loss: 0.4861 - val_accuracy: 0.9375 - val_loss: 0.5236
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9494 - loss: 0.4603 - val_accuracy: 0.9500 - val_loss: 0.5259
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9659 - loss: 0.4458 - val_accuracy: 0.9375 - val_loss: 0.5113
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.4357 - val_accuracy: 0.9531 - val_loss: 0.4976
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9584 - loss: 0.4154 - val_accuracy: 0.9531 - val_loss: 0.4881
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9563 - loss: 0.4405 - val_accuracy: 0.9406 - val_loss: 0.4732
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9653 - loss: 0.3885 - val_accuracy: 0.9594 - val_loss: 0.4643
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9703 - loss: 0.3811 - val_accuracy: 0.9625 - val_loss: 0.4508
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9752 - loss: 0.3762 - val_accuracy: 0.9500 - val_loss: 0.4431
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9750 - loss: 0.3756 - val_accuracy: 0.9563 - val_loss: 0.4496
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9764 - loss: 0.3619 - val_accuracy: 0.9531 - val_loss: 0.4778
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9762 - loss: 0.3462 - val_accuracy: 0.9625 - val_loss: 0.4542
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9790 - loss: 0.3449 - val_accuracy: 0.9531 - val_loss: 0.4592
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9706 - loss: 0.3689 - val_accuracy: 0.9594 - val_loss: 0.4481
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9664 - loss: 0.3683 - val_accuracy: 0.9625 - val_loss: 0.4364
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9799 - loss: 0.3485 - val_accuracy: 0.9469 - val_loss: 0.4824
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9839 - loss: 0.3309 - val_accuracy: 0.9750 - val_loss: 0.4296
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9830 - loss: 0.3276 - val_accuracy: 0.9688 - val_loss: 0.4288
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9839 - loss: 0.3262 - val_accuracy: 0.9656 - val_loss: 0.4320
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9851 - loss: 0.3180 - val_accuracy: 0.9750 - val_loss: 0.4291
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9862 - loss: 0.3142 - val_accuracy: 0.9688 - val_loss: 0.4327
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9860 - loss: 0.3124 - val_accuracy: 0.9688 - val_loss: 0.4248
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9852 - loss: 0.3154 - val_accuracy: 0.9750 - val_loss: 0.4202
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9896 - loss: 0.3021 - val_accuracy: 0.9594 - val_loss: 0.4432
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9840 - loss: 0.3073 - val_accuracy: 0.9625 - val_loss: 0.4418
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9848 - loss: 0.3068 - val_accuracy: 0.9563 - val_loss: 0.4640
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9768 - loss: 0.3234 - val_accuracy: 0.9750 - val_loss: 0.4157
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9909 - loss: 0.2940 - val_accuracy: 0.9656 - val_loss: 0.4329
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9884 - loss: 0.3109 - val_accuracy: 0.9500 - val_loss: 0.4660
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9828 - loss: 0.3007 - val_accuracy: 0.9688 - val_loss: 0.4349
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9805 - loss: 0.3044 - val_accuracy: 0.9656 - val_loss: 0.4444
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9915 - loss: 0.2824 - val_accuracy: 0.9750 - val_loss: 0.4163
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9886 - loss: 0.2904 - val_accuracy: 0.9594 - val_loss: 0.4317
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9808 - loss: 0.3057 - val_accuracy: 0.9625 - val_loss: 0.4531
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9850 - loss: 0.2936 - val_accuracy: 0.9750 - val_loss: 0.4323
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9841 - loss: 0.2912 - val_accuracy: 0.9719 - val_loss: 0.4127
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9900 - loss: 0.2825 - val_accuracy: 0.9781 - val_loss: 0.4224
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9901 - loss: 0.2848 - val_accuracy: 0.9750 - val_loss: 0.4190
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9911 - loss: 0.2737 - val_accuracy: 0.9781 - val_loss: 0.3949
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9900 - loss: 0.2811 - val_accuracy: 0.9719 - val_loss: 0.4035
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9870 - loss: 0.2867 - val_accuracy: 0.9750 - val_loss: 0.4091
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9918 - loss: 0.2758 - val_accuracy: 0.9781 - val_loss: 0.4025
# Epoch 1/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.1713 - loss: 2.3674 - val_accuracy: 0.2719 - val_loss: 2.1849
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3070 - loss: 2.1395 - val_accuracy: 0.5063 - val_loss: 1.8434
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5607 - loss: 1.7425 - val_accuracy: 0.6656 - val_loss: 1.2781
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7329 - loss: 1.2082 - val_accuracy: 0.8000 - val_loss: 1.0167
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8014 - loss: 0.9922 - val_accuracy: 0.8500 - val_loss: 0.8972
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8731 - loss: 0.8016 - val_accuracy: 0.8687 - val_loss: 0.8209
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8750 - loss: 0.7560 - val_accuracy: 0.8750 - val_loss: 0.7624
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8918 - loss: 0.6881 - val_accuracy: 0.9062 - val_loss: 0.7348
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9131 - loss: 0.6263 - val_accuracy: 0.8969 - val_loss: 0.7236
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9047 - loss: 0.6193 - val_accuracy: 0.9031 - val_loss: 0.7376
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9286 - loss: 0.5623 - val_accuracy: 0.9187 - val_loss: 0.7185
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9178 - loss: 0.5700 - val_accuracy: 0.8969 - val_loss: 0.7253
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9208 - loss: 0.5418 - val_accuracy: 0.9125 - val_loss: 0.7392
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9268 - loss: 0.5264 - val_accuracy: 0.9156 - val_loss: 0.7322
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9395 - loss: 0.4968 - val_accuracy: 0.9219 - val_loss: 0.7317
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9444 - loss: 0.4818 - val_accuracy: 0.9125 - val_loss: 0.7672
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9435 - loss: 0.4843 - val_accuracy: 0.9156 - val_loss: 0.7674
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9446 - loss: 0.4855 - val_accuracy: 0.9406 - val_loss: 0.7403
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9568 - loss: 0.4643 - val_accuracy: 0.9438 - val_loss: 0.7356
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9545 - loss: 0.4500 - val_accuracy: 0.9500 - val_loss: 0.7374
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9672 - loss: 0.4197 - val_accuracy: 0.9094 - val_loss: 0.7670
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9443 - loss: 0.4711 - val_accuracy: 0.9438 - val_loss: 0.7520
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9531 - loss: 0.4643 - val_accuracy: 0.9469 - val_loss: 0.7534
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9521 - loss: 0.4437 - val_accuracy: 0.9438 - val_loss: 0.7576
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9647 - loss: 0.4182 - val_accuracy: 0.9406 - val_loss: 0.7673
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9651 - loss: 0.4182 - val_accuracy: 0.9187 - val_loss: 0.7918
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9519 - loss: 0.4316 - val_accuracy: 0.9281 - val_loss: 0.7908
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9643 - loss: 0.4024 - val_accuracy: 0.9438 - val_loss: 0.7760
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9634 - loss: 0.4048 - val_accuracy: 0.9438 - val_loss: 0.7651
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9695 - loss: 0.3980 - val_accuracy: 0.9469 - val_loss: 0.7817
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9726 - loss: 0.3763 - val_accuracy: 0.9375 - val_loss: 0.8164
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9648 - loss: 0.4020 - val_accuracy: 0.9312 - val_loss: 0.8043
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9655 - loss: 0.3975 - val_accuracy: 0.9469 - val_loss: 0.7910
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9721 - loss: 0.3685 - val_accuracy: 0.9344 - val_loss: 0.8365
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9684 - loss: 0.3809 - val_accuracy: 0.9438 - val_loss: 0.8196
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9684 - loss: 0.3812 - val_accuracy: 0.9312 - val_loss: 0.8290
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9676 - loss: 0.3831 - val_accuracy: 0.9500 - val_loss: 0.7996
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9769 - loss: 0.3557 - val_accuracy: 0.9250 - val_loss: 0.8220
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9717 - loss: 0.3738 - val_accuracy: 0.9344 - val_loss: 0.8196
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9689 - loss: 0.3704 - val_accuracy: 0.9406 - val_loss: 0.8042
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9695 - loss: 0.3680 - val_accuracy: 0.9219 - val_loss: 0.8629
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9684 - loss: 0.3710 - val_accuracy: 0.9469 - val_loss: 0.8294
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9787 - loss: 0.3495 - val_accuracy: 0.9344 - val_loss: 0.8807
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9702 - loss: 0.3657 - val_accuracy: 0.9406 - val_loss: 0.8321
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9667 - loss: 0.3701 - val_accuracy: 0.9438 - val_loss: 0.8406
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9742 - loss: 0.3446 - val_accuracy: 0.9375 - val_loss: 0.8605
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9638 - loss: 0.3510 - val_accuracy: 0.9469 - val_loss: 0.8322
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9772 - loss: 0.3384 - val_accuracy: 0.9250 - val_loss: 0.8754
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9782 - loss: 0.3526 - val_accuracy: 0.9406 - val_loss: 0.8561
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9782 - loss: 0.3464 - val_accuracy: 0.9406 - val_loss: 0.8825
# Epoch 1/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.1559 - loss: 2.3663 - val_accuracy: 0.3031 - val_loss: 2.2311
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2610 - loss: 2.1753 - val_accuracy: 0.3438 - val_loss: 1.9702
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3537 - loss: 1.8273 - val_accuracy: 0.4375 - val_loss: 1.4946
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5316 - loss: 1.4404 - val_accuracy: 0.5813 - val_loss: 1.2739
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6341 - loss: 1.2754 - val_accuracy: 0.5750 - val_loss: 1.1919
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5803 - loss: 1.2371 - val_accuracy: 0.6125 - val_loss: 1.1603
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6449 - loss: 1.2387 - val_accuracy: 0.6625 - val_loss: 1.0931
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6359 - loss: 1.1515 - val_accuracy: 0.6625 - val_loss: 1.0849
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6489 - loss: 1.0973 - val_accuracy: 0.7188 - val_loss: 1.0713
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6718 - loss: 1.0791 - val_accuracy: 0.6719 - val_loss: 1.0492
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6821 - loss: 1.0506 - val_accuracy: 0.6562 - val_loss: 1.0334
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6916 - loss: 1.0491 - val_accuracy: 0.6812 - val_loss: 1.0220
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6686 - loss: 1.0522 - val_accuracy: 0.6500 - val_loss: 1.0305
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6944 - loss: 1.0291 - val_accuracy: 0.6812 - val_loss: 1.0025
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6848 - loss: 1.0146 - val_accuracy: 0.7344 - val_loss: 0.9861
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6859 - loss: 1.0143 - val_accuracy: 0.7469 - val_loss: 0.9868
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7105 - loss: 0.9948 - val_accuracy: 0.7781 - val_loss: 0.9913
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7044 - loss: 0.9957 - val_accuracy: 0.7437 - val_loss: 0.9708
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7471 - loss: 0.9559 - val_accuracy: 0.7000 - val_loss: 0.9609
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6863 - loss: 1.0128 - val_accuracy: 0.7188 - val_loss: 0.9662
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6825 - loss: 1.0455 - val_accuracy: 0.6656 - val_loss: 0.9762
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6889 - loss: 0.9992 - val_accuracy: 0.6969 - val_loss: 0.9641
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7066 - loss: 0.9871 - val_accuracy: 0.7000 - val_loss: 0.9477
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7330 - loss: 0.9589 - val_accuracy: 0.6969 - val_loss: 0.9738
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6770 - loss: 0.9667 - val_accuracy: 0.7500 - val_loss: 0.9544
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7129 - loss: 0.9636 - val_accuracy: 0.7469 - val_loss: 0.9464
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7389 - loss: 0.9279 - val_accuracy: 0.6812 - val_loss: 0.9864
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7040 - loss: 0.9402 - val_accuracy: 0.6938 - val_loss: 0.9505
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7083 - loss: 0.9815 - val_accuracy: 0.7719 - val_loss: 0.9485
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7156 - loss: 0.9340 - val_accuracy: 0.7125 - val_loss: 0.9399
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6927 - loss: 0.9046 - val_accuracy: 0.7281 - val_loss: 0.9785
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7288 - loss: 0.9504 - val_accuracy: 0.7000 - val_loss: 0.9480
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7015 - loss: 0.9232 - val_accuracy: 0.6687 - val_loss: 1.0438
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7432 - loss: 0.9370 - val_accuracy: 0.7094 - val_loss: 0.9486
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7398 - loss: 0.8945 - val_accuracy: 0.7688 - val_loss: 0.9372
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7461 - loss: 0.9217 - val_accuracy: 0.6812 - val_loss: 0.9626
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7344 - loss: 0.9190 - val_accuracy: 0.7781 - val_loss: 0.9411
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7456 - loss: 0.9091 - val_accuracy: 0.7719 - val_loss: 0.9274
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7370 - loss: 0.9043 - val_accuracy: 0.7625 - val_loss: 0.9462
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7097 - loss: 0.9008 - val_accuracy: 0.7406 - val_loss: 0.9621
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7503 - loss: 0.8805 - val_accuracy: 0.6906 - val_loss: 0.9658
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7053 - loss: 0.8936 - val_accuracy: 0.7125 - val_loss: 0.9601
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7336 - loss: 0.9465 - val_accuracy: 0.6969 - val_loss: 0.9358
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7225 - loss: 0.8685 - val_accuracy: 0.7812 - val_loss: 0.9269
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7494 - loss: 0.9003 - val_accuracy: 0.6750 - val_loss: 0.9670
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7228 - loss: 0.8821 - val_accuracy: 0.7406 - val_loss: 0.9598
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7545 - loss: 0.8762 - val_accuracy: 0.7688 - val_loss: 0.9466
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7448 - loss: 0.9018 - val_accuracy: 0.7625 - val_loss: 0.9361
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7259 - loss: 0.9215 - val_accuracy: 0.7250 - val_loss: 0.9755
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7376 - loss: 0.9099 - val_accuracy: 0.7781 - val_loss: 0.9196

# %% [markdown]
# ## Model Evaluation

# %%
# plot training & validation loss values
plt.plot(history_all.history['loss'], label='Training Loss')
plt.plot(history_all.history['val_loss'], label='Validation Loss')
plt.title('MLP ASM and Bytes Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
# plot training & validation loss values
plt.plot(history_asm.history['loss'], label='Training Loss')
plt.plot(history_asm.history['val_loss'], label='Validation Loss')
plt.title('MLP ASM Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
# plot training & validation loss values
plt.plot(history_bytes.history['loss'], label='Training Loss')
plt.plot(history_bytes.history['val_loss'], label='Validation Loss')
plt.title('MLP Bytes Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

y_pred_prob_all = model_all.predict(X_test_all, verbose=False)
y_pred_all = np.argmax(y_pred_prob_all, axis=1) + 1
y_true_all = np.argmax(y_test_one_hot_all, axis=1) + 1
y_pred_prob_asm = model_asm.predict(X_test_asm, verbose=False)
y_pred_asm = np.argmax(y_pred_prob_asm, axis=1) + 1
y_true_asm = np.argmax(y_test_one_hot_asm, axis=1) + 1
y_pred_prob_bytes = model_bytes.predict(X_test_bytes, verbose=False)
y_pred_bytes = np.argmax(y_pred_prob_bytes, axis=1) + 1
y_true_bytes = np.argmax(y_test_one_hot_bytes, axis=1) + 1

# %% [markdown]
# ## ASM and Bytes Confusion Matrix

# %%
print(classification_report(y_true_all, y_pred_all, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.97      0.93      0.95        40
#            2       1.00      0.97      0.99        40
#            3       1.00      0.97      0.99        40
#            4       0.95      1.00      0.98        40
#            5       0.95      1.00      0.98        40
#            6       0.95      1.00      0.98        40
#            7       1.00      0.95      0.97        40
#            8       1.00      1.00      1.00        40
#
#     accuracy                           0.98       320
#    macro avg       0.98      0.98      0.98       320
# weighted avg       0.98      0.98      0.98       320

# %%
# confusion matrix
cm = confusion_matrix(y_true_all, y_pred_all)
ConfusionMatrixDisplay(cm).plot()

# %% [markdown]
# ## ASM Confusion Matrix

# %%
print(classification_report(y_true_asm, y_pred_asm, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.88      0.93      0.90        40
#            2       1.00      0.90      0.95        40
#            3       0.97      0.97      0.97        40
#            4       1.00      0.97      0.99        40
#            5       0.89      0.97      0.93        40
#            6       0.97      0.95      0.96        40
#            7       0.94      0.85      0.89        40
#            8       0.89      0.97      0.93        40
#
#     accuracy                           0.94       320
#    macro avg       0.94      0.94      0.94       320
# weighted avg       0.94      0.94      0.94       320

# %%
# confusion matrix
cm = confusion_matrix(y_true_asm, y_pred_asm)
ConfusionMatrixDisplay(cm).plot()

# %% [markdown]
# ## Bytes Confusion Matrix

# %%
print(classification_report(y_true_bytes, y_pred_bytes, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.57      0.75      0.65        40
#            2       0.78      0.78      0.78        40
#            3       1.00      0.97      0.99        40
#            4       0.85      1.00      0.92        40
#            5       0.73      0.47      0.58        40
#            6       0.95      0.88      0.91        40
#            7       0.67      0.75      0.71        40
#            8       0.76      0.62      0.68        40
#
#     accuracy                           0.78       320
#    macro avg       0.79      0.78      0.78       320
# weighted avg       0.79      0.78      0.78       320

# %%
# confusion matrix
cm = confusion_matrix(y_true_bytes, y_pred_bytes)
ConfusionMatrixDisplay(cm).plot()

# %% [markdown]
# ## ASM and Bytes MLogLoss

# %%
from sklearn.metrics import log_loss
# Calculate the mlogloss
mlogloss_all = log_loss(y_test_one_hot_all, y_pred_prob_all)
print(f"Multiclass Log Loss: {mlogloss_all}")
# Out:
# Multiclass Log Loss: 0.2405776637104365

# %% [markdown]
# ## ASM MLogLoss

# %%
# Calculate the mlogloss
mlogloss_asm = log_loss(y_test_one_hot_asm, y_pred_prob_asm)
print(f"Multiclass Log Loss: {mlogloss_asm}")
# Out:
# Multiclass Log Loss: 0.4559629943864458

# %% [markdown]
# ## Bytes MLogLoss

# %%
# Calculate the mlogloss
mlogloss_bytes = log_loss(y_test_one_hot_bytes, y_pred_prob_bytes)
print(f"Multiclass Log Loss: {mlogloss_bytes}")
# Out:
# Multiclass Log Loss: 0.7538467395477495

# %% [markdown]
# ## Save the Models

# %%
model_all.save('mlp_all.h5')
model_asm.save('mlp_asm.h5')
model_bytes.save('mlp_bytes.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# prompt: loading a saved model

# Load the saved models
model_all_test = tf.keras.models.load_model('mlp_all.h5')
model_asm_test = tf.keras.models.load_model('mlp_asm.h5')
model_bytes_test = tf.keras.models.load_model('mlp_bytes.h5')

# Now you can use the loaded models for prediction or further training
# Example:
y_pred_all_test = np.argmax(model_all.predict(X_test_all), axis = 1) + 1

# confusion matrix
cm = confusion_matrix(y_true_all, y_pred_all_test)
ConfusionMatrixDisplay(cm).plot()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
from tensorflow.keras.models import Model
# Extract embeddings from each model
mlp_all_embedding = tf.keras.models.load_model('mlp_all.h5')
mlp_asm_embedding = tf.keras.models.load_model('mlp_asm.h5')
mlp_bytes_embedding = tf.keras.models.load_model('mlp_bytes.h5')

mlp_all_embedding = Model(inputs=mlp_all_embedding.inputs, outputs=mlp_all_embedding.layers[-2].output)
mlp_asm_embedding = Model(inputs=mlp_asm_embedding.inputs, outputs=mlp_asm_embedding.layers[-2].output)
mlp_bytes_embedding = Model(inputs=mlp_bytes_embedding.inputs, outputs=mlp_bytes_embedding.layers[-2].output)

mlp_all_embeddings = mlp_all_embedding.predict(X_test_all)
mlp_asm_embeddings = mlp_asm_embedding.predict(X_test_asm)
mlp_bytes_embeddings = mlp_bytes_embedding.predict(X_test_bytes)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
y_pred_prob_all = mlp_all_embedding.predict(X_test_all, verbose=False)
y_pred_all = np.argmax(y_pred_prob_all, axis=1) + 1
y_true_all = np.argmax(y_test_one_hot_all, axis=1) + 1
y_pred_prob_asm = mlp_asm_embedding.predict(X_test_asm, verbose=False)
y_pred_asm = np.argmax(y_pred_prob_asm, axis=1) + 1
y_true_asm = np.argmax(y_test_one_hot_asm, axis=1) + 1
y_pred_prob_bytes = mlp_bytes_embedding.predict(X_test_bytes, verbose=False)
y_pred_bytes = np.argmax(y_pred_prob_bytes, axis=1) + 1
y_true_bytes = np.argmax(y_test_one_hot_bytes, axis=1) + 1

# %%
# Embedding Visualization ASM + Bytes
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

class_labels_all = y_true_all

tsne_all = TSNE(n_components=2)
embeddings_2d_all = tsne_all.fit_transform(mlp_all_embeddings)

plt.figure(figsize=(8, 6))
num_classes_all = len(set(class_labels_all))  # Total number of unique classes
colors = plt.cm.get_cmap("tab10", num_classes_all)  # Choose a colormap with distinct colors

for class_index in range(num_classes_all):
    # Select points for the current class
    indices = np.where(np.array(class_labels_all) == class_index)
    plt.scatter(
        embeddings_2d_all[indices, 0],
        embeddings_2d_all[indices, 1],
        label=f"Class {class_index}",
        color=colors(class_index)
    )

plt.xlabel('TSNE Dimension 1')
plt.ylabel('TSNE Dimension 2')
plt.title('Embedding Visualization MLP ASM and Bytes')
plt.legend()
plt.show()
# Out:
# <ipython-input-53-e9106cd51482>:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap("tab10", num_classes_all)  # Choose a colormap with distinct colors

# %%
# Embedding Visualization ASM
class_labels_asm = y_true_asm

tsne_asm = TSNE(n_components=2)
embeddings_2d_asm = tsne_asm.fit_transform(mlp_asm_embeddings)

plt.figure(figsize=(8, 6))
num_classes_asm = len(set(class_labels_asm))  # Total number of unique classes
colors = plt.cm.get_cmap("tab10", num_classes_asm)  # Choose a colormap with distinct colors

for class_index in range(num_classes_asm):
    # Select points for the current class
    indices = np.where(np.array(class_labels_asm) == class_index)
    plt.scatter(
        embeddings_2d_asm[indices, 0],
        embeddings_2d_asm[indices, 1],
        label=f"Class {class_index}",
        color=colors(class_index)
    )

plt.xlabel('TSNE Dimension 1')
plt.ylabel('TSNE Dimension 2')
plt.title('Embedding Visualization MLP ASM')
plt.legend()
plt.show()
# Out:
# <ipython-input-54-75e03e5aa7d5>:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap("tab10", num_classes_asm)  # Choose a colormap with distinct colors

# %%
# Embedding Visualization Bytes
class_labels_bytes = y_true_bytes

tsne_bytes = TSNE(n_components=2)
embeddings_2d_bytes = tsne_bytes.fit_transform(mlp_bytes_embeddings)

plt.figure(figsize=(8, 6))
num_classes_bytes = len(set(class_labels_bytes))  # Total number of unique classes
colors = plt.cm.get_cmap("tab10", num_classes_bytes)  # Choose a colormap with distinct colors

for class_index in range(num_classes_bytes):
    # Select points for the current class
    indices = np.where(np.array(class_labels_bytes) == class_index)
    plt.scatter(
        embeddings_2d_bytes[indices, 0],
        embeddings_2d_bytes[indices, 1],
        label=f"Class {class_index}",
        color=colors(class_index)
    )

plt.xlabel('TSNE Dimension 1')
plt.ylabel('TSNE Dimension 2')
plt.title('Embedding Visualization MLP Bytes')
plt.legend()
plt.show()
# Out:
# <ipython-input-55-e8a031f2d7c6>:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap("tab10", num_classes_bytes)  # Choose a colormap with distinct colors
